# %% [markdown]
# ## 准备数据

# %%
import torch
import torch.nn as nn
import torch.utils.data as data
import torch.optim as optim
import torch.nn.functional as F
import numpy as np
import pickle
from sklearn.model_selection import train_test_split

def unpickle(file):
    with open(file, 'rb') as fo:
        dict = pickle.load(fo, encoding='latin1')
    return dict

cifar10_dir = '/home/lc/d2l-zh/exercise/cifar-10-python/cifar-10-batches-py/'
all_train_data = []
all_train_labels = []

for i in range(1, 6):
    file_path = f'{cifar10_dir}/data_batch_{i}'
    data_dict = unpickle(file_path)
    all_train_data.append(data_dict['data'])
    all_train_labels.extend(data_dict['labels'])

train_data_np = np.concatenate(all_train_data)
train_labels_np = np.array(all_train_labels)

X_train, X_val, y_train, y_val = train_test_split(
    train_data_np, 
    train_labels_np, 
    test_size=0.1, 
    random_state=42,
    stratify=train_labels_np 
)

test_file_path = f'{cifar10_dir}/test_batch'
test_dict = unpickle(test_file_path)
X_test = test_dict['data']
y_test = np.array(test_dict['labels'])

print(f"测试数据 (X_test) 形状: {X_test.shape}")
print(f"测试标签 (y_test) 形状: {y_test.shape}")

print(f"原始训练数据形状: {train_data_np.shape}")
print("-" * 30)
print(f"划分后的训练数据 (X_train) 形状: {X_train.shape}")
print(f"划分后的训练标签 (y_train) 形状: {y_train.shape}")
print(f"划分后的验证数据 (X_val) 形状: {X_val.shape}")
print(f"划分后的验证标签 (y_val) 形状: {y_val.shape}")
# Out:
# 测试数据 (X_test) 形状: (10000, 3072)
# 测试标签 (y_test) 形状: (10000,)
# 原始训练数据形状: (50000, 3072)
# ------------------------------
# 划分后的训练数据 (X_train) 形状: (45000, 3072)
# 划分后的训练标签 (y_train) 形状: (45000,)
# 划分后的验证数据 (X_val) 形状: (5000, 3072)
# 划分后的验证标签 (y_val) 形状: (5000,)

# %%
class SimpleCIFAR10Dataset(data.Dataset):
    def __init__(self, images, labels):
        """
        初始化函数。
        Args:
            images (numpy.ndarray): 图像数据，形状为 (样本数, 3072)，代表一维形式。
            labels (numpy.ndarray): 标签数据，形状为 (样本数,)。
        """
        self.images = torch.from_numpy(images / 255.0).float()
        self.labels = torch.from_numpy(labels).long() 

    def __len__(self):
        """返回数据集的样本总数。"""
        return len(self.labels)

    def __getitem__(self, idx):
        """根据索引获取一个样本（图像和标签）。"""
        image = self.images[idx]
        label = self.labels[idx]
        image = image.reshape(3, 32, 32) 
        return image, label

# 1. 实例化训练和验证数据集
train_dataset = SimpleCIFAR10Dataset(X_train, y_train)
val_dataset = SimpleCIFAR10Dataset(X_val, y_val)
test_dataset = SimpleCIFAR10Dataset(X_test, y_test)

# 2. 创建 DataLoader
batch_size = 2000  # 定义每个批次的大小

train_loader = data.DataLoader(
    dataset=train_dataset,
    batch_size=batch_size,
    shuffle=True,  # 训练时打乱数据顺序以增强模型泛化能力
    num_workers=16, # 增加工作进程数
    pin_memory=True
)

val_loader = data.DataLoader(
    dataset=val_dataset,
    batch_size=batch_size,
    shuffle=False, # 验证时通常不需要打乱
    num_workers=16, # 增加工作进程数
    pin_memory=True
)

test_loader = data.DataLoader(
    dataset=test_dataset,
    batch_size=batch_size, # 可以和训练时用一样的batch_size
    shuffle=False,      # 测试时不需要打乱数据
    num_workers=16, # 增加工作进程数
    pin_memory=True
)

# 3. 验证 DataLoader 是否工作正常
print("成功创建最简化的 DataLoader！")
print("-" * 30)

# 从 train_loader 中获取一个批次的数据进行检查
data_batch, labels_batch = next(iter(train_loader))
print(f"一个训练批次的数据 (images) 形状: {data_batch.shape}")
print(f"一个训练批次的标签 (labels) 形状: {labels_batch.shape}")
print(f"批次数据的类型: {data_batch.dtype}")
print(f"批次标签的类型: {labels_batch.dtype}")
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
# Out:
# 成功创建最简化的 DataLoader！
# ------------------------------
# 一个训练批次的数据 (images) 形状: torch.Size([2000, 3, 32, 32])
# 一个训练批次的标签 (labels) 形状: torch.Size([2000])
# 批次数据的类型: torch.float32
# 批次标签的类型: torch.int64
# Using device: cuda

# %% [markdown]
# ## 建立模型

# %%
class myModel(nn.Module):
    def __init__(self):
        super(myModel,self).__init__()
        self.conv1 = nn.Conv2d(in_channels=3, out_channels=16, kernel_size=5, padding=2) # 3x32x32 -> 16x32x32
        self.pool = nn.MaxPool2d(kernel_size=2, stride=2) # 16x32x32 -> 16x16x16
        self.conv2 = nn.Conv2d(in_channels=16, out_channels=32, kernel_size=5, padding=2) # 16x16x16 -> 32x16x16
        self.fc1 = nn.Linear(32 * 8 * 8, 128)
        self.fc2 = nn.Linear(128, 10)
    def forward(self, inp):
        x = self.pool(F.relu(self.conv1(inp)))
        x = self.pool(F.relu(self.conv2(x)))
        x = x.view(-1, 32 * 8 * 8) 
        x = F.relu(self.fc1(x))
        logits = self.fc2(x)
        return logits
        
model = myModel()

optimizer = optim.Adam(model.parameters(),lr = 0.001, weight_decay=1e-3)
# optimizer = optim.Adam(model.parameters(),lr = 0.001)

def eval_model(model, test_loader, criterion):
    """
    在测试集上评估模型的最终性能。
    """
    model.eval()  # 切换到评估模式
    test_loss = 0.0
    correct = 0
    total = 0
    with torch.no_grad(): # 在此模式下，所有计算都不会被记录用于反向传播
        for images, labels in test_loader:
            images = images.to(device)
            labels = labels.to(device)
            outputs = model(images)
            loss = criterion(outputs, labels)
            test_loss += loss.item()

            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

    # 计算平均损失和准确率
    avg_loss = test_loss / len(test_loader)
    accuracy = 100 * correct / total

    return accuracy, avg_loss

# %% [markdown]
# ## 计算 loss

# %%
criterion = nn.CrossEntropyLoss()

# %% [markdown]
# ## 实际训练

# %%
num_epochs = 200
def train_one_step(model,optimizer,train_loader):
    model.train()
    for x_batch,y_batch in train_loader:
        x_batch = x_batch.to(device)
        y_batch = y_batch.to(device)
        optimizer.zero_grad()
        logits = model(x_batch)
        loss =  criterion(logits,y_batch)
        loss.backward()
        optimizer.step()

if __name__ == '__main__':
    model.to(device)
    best_val_accuracy = 0.0
    best_model_path = "best_model.pth"
    for i in range(num_epochs):
        train_one_step(model,optimizer,train_loader)
        train_accuracy, train_loss = eval_model(model, train_loader, criterion)
        val_accuracy, val_loss = eval_model(model, val_loader, criterion)
        print("-" * 30)
        print(f'Epoch [{i+1}/{num_epochs}] 的训练集准确率: {train_accuracy:.2f} %')
        print(f'Epoch [{i+1}/{num_epochs}] 的训练集loss: {train_loss:.2f}')
        print(f'Epoch [{i+1}/{num_epochs}] 的验证集准确率: {val_accuracy:.2f} %')
        print(f'Epoch [{i+1}/{num_epochs}] 的验证集loss: {val_loss:.2f}')
        if val_accuracy > best_val_accuracy:
            best_val_accuracy = val_accuracy
            torch.save(model.state_dict(), best_model_path)
            print(f"发现更好的模型，已保存到 {best_model_path}")
        print("-" * 30)
    print(f"加载最佳模型 ({best_model_path}) 进行最终测试...")
    model.load_state_dict(torch.load(best_model_path))

    # 使用加载了最佳权重的模型进行测试
    test_accuracy, test_loss = eval_model(model, test_loader, criterion)
    print(f'测试集准确率: {test_accuracy:.2f} %')
    print(f'测试集loss: {test_loss:.2f} %')
# Out:
# ------------------------------
# Epoch [1/200] 的训练集准确率: 32.70 %
# Epoch [1/200] 的训练集loss: 1.94
# Epoch [1/200] 的验证集准确率: 31.98 %
# Epoch [1/200] 的验证集loss: 1.94
# 发现更好的模型，已保存到 best_model.pth
# ------------------------------
# ------------------------------
# Epoch [2/200] 的训练集准确率: 36.54 %
# Epoch [2/200] 的训练集loss: 1.78
# Epoch [2/200] 的验证集准确率: 36.24 %
# Epoch [2/200] 的验证集loss: 1.78
# 发现更好的模型，已保存到 best_model.pth
# ------------------------------
# ------------------------------
# Epoch [3/200] 的训练集准确率: 41.34 %
# Epoch [3/200] 的训练集loss: 1.64
# Epoch [3/200] 的验证集准确率: 41.22 %
# Epoch [3/200] 的验证集loss: 1.64
# 发现更好的模型，已保存到 best_model.pth
# ------------------------------
# ------------------------------
# Epoch [4/200] 的训练集准确率: 43.77 %
# Epoch [4/200] 的训练集loss: 1.58
# Epoch [4/200] 的验证集准确率: 43.50 %
# Epoch [4/200] 的验证集loss: 1.57
# 发现更好的模型，已保存到 best_model.pth
# ------------------------------
# ------------------------------
# Epoch [5/200] 的训练集准确率: 46.25 %
# Epoch [5/200] 的训练集loss: 1.50
# Epoch [5/200] 的验证集准确率: 45.30 %
# Epoch [5/200] 的验证集loss: 1.50
# 发现更好的模型，已保存到 best_model.pth
# ------------------------------
# ------------------------------
# Epoch [6/200] 的训练集准确率: 47.68 %
# Epoch [6/200] 的训练集loss: 1.47
# Epoch [6/200] 的验证集准确率: 46.50 %
# Epoch [6/200] 的验证集loss: 1.46
# 发现更好的模型，已保存到 best_model.pth
# ------------------------------
# ------------------------------
# Epoch [7/200] 的训练集准确率: 48.02 %
# Epoch [7/200] 的训练集loss: 1.44
# Epoch [7/200] 的验证集准确率: 47.10 %
# Epoch [7/200] 的验证集loss: 1.44
# 发现更好的模型，已保存到 best_model.pth
# ------------------------------
# ------------------------------
# Epoch [8/200] 的训练集准确率: 49.64 %
# Epoch [8/200] 的训练集loss: 1.40
# Epoch [8/200] 的验证集准确率: 48.82 %
# Epoch [8/200] 的验证集loss: 1.40
# 发现更好的模型，已保存到 best_model.pth
# ------------------------------
# ------------------------------
# Epoch [9/200] 的训练集准确率: 50.69 %
# Epoch [9/200] 的训练集loss: 1.39
# Epoch [9/200] 的验证集准确率: 49.82 %
# Epoch [9/200] 的验证集loss: 1.40
# 发现更好的模型，已保存到 best_model.pth
# ------------------------------
# ------------------------------
# Epoch [10/200] 的训练集准确率: 52.91 %
# Epoch [10/200] 的训练集loss: 1.34
# Epoch [10/200] 的验证集准确率: 52.52 %
# Epoch [10/200] 的验证集loss: 1.34
# 发现更好的模型，已保存到 best_model.pth
# ------------------------------
# ------------------------------
# Epoch [11/200] 的训练集准确率: 53.48 %
# Epoch [11/200] 的训练集loss: 1.32
# Epoch [11/200] 的验证集准确率: 52.92 %
# Epoch [11/200] 的验证集loss: 1.33
# 发现更好的模型，已保存到 best_model.pth
# ------------------------------
# ------------------------------
# Epoch [12/200] 的训练集准确率: 54.74 %
# Epoch [12/200] 的训练集loss: 1.29
# Epoch [12/200] 的验证集准确率: 54.44 %
# Epoch [12/200] 的验证集loss: 1.29
# 发现更好的模型，已保存到 best_model.pth
# ------------------------------
# ------------------------------
# Epoch [13/200] 的训练集准确率: 54.95 %
# Epoch [13/200] 的训练集loss: 1.28
# Epoch [13/200] 的验证集准确率: 54.14 %
# Epoch [13/200] 的验证集loss: 1.29
# ------------------------------
# ------------------------------
# Epoch [14/200] 的训练集准确率: 55.32 %
# Epoch [14/200] 的训练集loss: 1.27
# Epoch [14/200] 的验证集准确率: 54.60 %
# Epoch [14/200] 的验证集loss: 1.27
# 发现更好的模型，已保存到 best_model.pth
# ------------------------------
# ------------------------------
# Epoch [15/200] 的训练集准确率: 56.31 %
# Epoch [15/200] 的训练集loss: 1.24
# Epoch [15/200] 的验证集准确率: 55.54 %
# Epoch [15/200] 的验证集loss: 1.25
# 发现更好的模型，已保存到 best_model.pth
# ------------------------------
# ------------------------------
# Epoch [16/200] 的训练集准确率: 56.83 %
# Epoch [16/200] 的训练集loss: 1.22
# Epoch [16/200] 的验证集准确率: 55.98 %
# Epoch [16/200] 的验证集loss: 1.24
# 发现更好的模型，已保存到 best_model.pth
# ------------------------------
# ------------------------------
# Epoch [17/200] 的训练集准确率: 55.57 %
# Epoch [17/200] 的训练集loss: 1.25
# Epoch [17/200] 的验证集准确率: 54.96 %
# Epoch [17/200] 的验证集loss: 1.26
# ------------------------------
# ------------------------------
# Epoch [18/200] 的训练集准确率: 56.57 %
# Epoch [18/200] 的训练集loss: 1.22
# Epoch [18/200] 的验证集准确率: 56.22 %
# Epoch [18/200] 的验证集loss: 1.23
# 发现更好的模型，已保存到 best_model.pth
# ------------------------------
# ------------------------------
# Epoch [19/200] 的训练集准确率: 57.54 %
# Epoch [19/200] 的训练集loss: 1.21
# Epoch [19/200] 的验证集准确率: 55.94 %
# Epoch [19/200] 的验证集loss: 1.22
# ------------------------------
# ------------------------------
# Epoch [20/200] 的训练集准确率: 59.17 %
# Epoch [20/200] 的训练集loss: 1.17
# Epoch [20/200] 的验证集准确率: 57.78 %
# Epoch [20/200] 的验证集loss: 1.19
# 发现更好的模型，已保存到 best_model.pth
# ------------------------------
# ------------------------------
# Epoch [21/200] 的训练集准确率: 59.59 %
# Epoch [21/200] 的训练集loss: 1.15
# Epoch [21/200] 的验证集准确率: 58.78 %
# Epoch [21/200] 的验证集loss: 1.17
# 发现更好的模型，已保存到 best_model.pth
# ------------------------------
# ------------------------------
# Epoch [22/200] 的训练集准确率: 59.73 %
# Epoch [22/200] 的训练集loss: 1.14
# Epoch [22/200] 的验证集准确率: 58.58 %
# Epoch [22/200] 的验证集loss: 1.17
# ------------------------------
# ------------------------------
# Epoch [23/200] 的训练集准确率: 60.46 %
# Epoch [23/200] 的训练集loss: 1.13
# Epoch [23/200] 的验证集准确率: 59.00 %
# Epoch [23/200] 的验证集loss: 1.15
# 发现更好的模型，已保存到 best_model.pth
# ------------------------------
# ------------------------------
# Epoch [24/200] 的训练集准确率: 60.69 %
# Epoch [24/200] 的训练集loss: 1.12
# Epoch [24/200] 的验证集准确率: 59.26 %
# Epoch [24/200] 的验证集loss: 1.15
# 发现更好的模型，已保存到 best_model.pth
# ------------------------------
# ------------------------------
# Epoch [25/200] 的训练集准确率: 61.04 %
# Epoch [25/200] 的训练集loss: 1.11
# Epoch [25/200] 的验证集准确率: 60.04 %
# Epoch [25/200] 的验证集loss: 1.14
# 发现更好的模型，已保存到 best_model.pth
# ------------------------------
# ------------------------------
# Epoch [26/200] 的训练集准确率: 61.16 %
# Epoch [26/200] 的训练集loss: 1.11
# Epoch [26/200] 的验证集准确率: 59.50 %
# Epoch [26/200] 的验证集loss: 1.14
# ------------------------------
# ------------------------------
# Epoch [27/200] 的训练集准确率: 61.37 %
# Epoch [27/200] 的训练集loss: 1.10
# Epoch [27/200] 的验证集准确率: 59.36 %
# Epoch [27/200] 的验证集loss: 1.14
# ------------------------------
# ------------------------------
# Epoch [28/200] 的训练集准确率: 61.84 %
# Epoch [28/200] 的训练集loss: 1.08
# Epoch [28/200] 的验证集准确率: 60.84 %
# Epoch [28/200] 的验证集loss: 1.12
# 发现更好的模型，已保存到 best_model.pth
# ------------------------------
# ------------------------------
# Epoch [29/200] 的训练集准确率: 62.58 %
# Epoch [29/200] 的训练集loss: 1.07
# Epoch [29/200] 的验证集准确率: 61.28 %
# Epoch [29/200] 的验证集loss: 1.11
# 发现更好的模型，已保存到 best_model.pth
# ------------------------------
# ------------------------------
# Epoch [30/200] 的训练集准确率: 61.64 %
# Epoch [30/200] 的训练集loss: 1.09
# Epoch [30/200] 的验证集准确率: 59.18 %
# Epoch [30/200] 的验证集loss: 1.13
# ------------------------------
# ------------------------------
# Epoch [31/200] 的训练集准确率: 62.65 %
# Epoch [31/200] 的训练集loss: 1.06
# Epoch [31/200] 的验证集准确率: 60.64 %
# Epoch [31/200] 的验证集loss: 1.11
# ------------------------------
# ------------------------------
# Epoch [32/200] 的训练集准确率: 63.87 %
# Epoch [32/200] 的训练集loss: 1.04
# Epoch [32/200] 的验证集准确率: 61.58 %
# Epoch [32/200] 的验证集loss: 1.09
# 发现更好的模型，已保存到 best_model.pth
# ------------------------------
# ------------------------------
# Epoch [33/200] 的训练集准确率: 63.00 %
# Epoch [33/200] 的训练集loss: 1.04
# Epoch [33/200] 的验证集准确率: 61.46 %
# Epoch [33/200] 的验证集loss: 1.10
# ------------------------------
# ------------------------------
# Epoch [34/200] 的训练集准确率: 63.63 %
# Epoch [34/200] 的训练集loss: 1.04
# Epoch [34/200] 的验证集准确率: 61.14 %
# Epoch [34/200] 的验证集loss: 1.09
# ------------------------------
# ------------------------------
# Epoch [35/200] 的训练集准确率: 63.78 %
# Epoch [35/200] 的训练集loss: 1.03
# Epoch [35/200] 的验证集准确率: 61.64 %
# Epoch [35/200] 的验证集loss: 1.09
# 发现更好的模型，已保存到 best_model.pth
# ------------------------------
# ------------------------------
# Epoch [36/200] 的训练集准确率: 64.39 %
# Epoch [36/200] 的训练集loss: 1.02
# Epoch [36/200] 的验证集准确率: 62.22 %
# Epoch [36/200] 的验证集loss: 1.07
# 发现更好的模型，已保存到 best_model.pth
# ------------------------------
# ------------------------------
# Epoch [37/200] 的训练集准确率: 64.23 %
# Epoch [37/200] 的训练集loss: 1.02
# Epoch [37/200] 的验证集准确率: 62.02 %
# Epoch [37/200] 的验证集loss: 1.09
# ------------------------------
# ------------------------------
# Epoch [38/200] 的训练集准确率: 65.03 %
# Epoch [38/200] 的训练集loss: 1.00
# Epoch [38/200] 的验证集准确率: 62.28 %
# Epoch [38/200] 的验证集loss: 1.06
# 发现更好的模型，已保存到 best_model.pth
# ------------------------------
# ------------------------------
# Epoch [39/200] 的训练集准确率: 65.65 %
# Epoch [39/200] 的训练集loss: 0.99
# Epoch [39/200] 的验证集准确率: 63.60 %
# Epoch [39/200] 的验证集loss: 1.05
# 发现更好的模型，已保存到 best_model.pth
# ------------------------------
# ------------------------------
# Epoch [40/200] 的训练集准确率: 65.14 %
# Epoch [40/200] 的训练集loss: 0.99
# Epoch [40/200] 的验证集准确率: 62.44 %
# Epoch [40/200] 的验证集loss: 1.06
# ------------------------------
# ------------------------------
# Epoch [41/200] 的训练集准确率: 65.68 %
# Epoch [41/200] 的训练集loss: 0.98
# Epoch [41/200] 的验证集准确率: 63.28 %
# Epoch [41/200] 的验证集loss: 1.04
# ------------------------------
# ------------------------------
# Epoch [42/200] 的训练集准确率: 66.37 %
# Epoch [42/200] 的训练集loss: 0.97
# Epoch [42/200] 的验证集准确率: 63.90 %
# Epoch [42/200] 的验证集loss: 1.04
# 发现更好的模型，已保存到 best_model.pth
# ------------------------------
# ------------------------------
# Epoch [43/200] 的训练集准确率: 65.86 %
# Epoch [43/200] 的训练集loss: 0.97
# Epoch [43/200] 的验证集准确率: 63.30 %
# Epoch [43/200] 的验证集loss: 1.04
# ------------------------------
# ------------------------------
# Epoch [44/200] 的训练集准确率: 66.58 %
# Epoch [44/200] 的训练集loss: 0.95
# Epoch [44/200] 的验证集准确率: 63.10 %
# Epoch [44/200] 的验证集loss: 1.03
# ------------------------------
# ------------------------------
# Epoch [45/200] 的训练集准确率: 66.42 %
# Epoch [45/200] 的训练集loss: 0.97
# Epoch [45/200] 的验证集准确率: 62.64 %
# Epoch [45/200] 的验证集loss: 1.05
# ------------------------------
# ------------------------------
# Epoch [46/200] 的训练集准确率: 66.66 %
# Epoch [46/200] 的训练集loss: 0.95
# Epoch [46/200] 的验证集准确率: 63.70 %
# Epoch [46/200] 的验证集loss: 1.03
# ------------------------------
# ------------------------------
# Epoch [47/200] 的训练集准确率: 65.33 %
# Epoch [47/200] 的训练集loss: 0.98
# Epoch [47/200] 的验证集准确率: 62.08 %
# Epoch [47/200] 的验证集loss: 1.07
# ------------------------------
# ------------------------------
# Epoch [48/200] 的训练集准确率: 67.37 %
# Epoch [48/200] 的训练集loss: 0.94
# Epoch [48/200] 的验证集准确率: 64.24 %
# Epoch [48/200] 的验证集loss: 1.02
# 发现更好的模型，已保存到 best_model.pth
# ------------------------------
# ------------------------------
# Epoch [49/200] 的训练集准确率: 67.76 %
# Epoch [49/200] 的训练集loss: 0.92
# Epoch [49/200] 的验证集准确率: 64.28 %
# Epoch [49/200] 的验证集loss: 1.01
# 发现更好的模型，已保存到 best_model.pth
# ------------------------------
# ------------------------------
# Epoch [50/200] 的训练集准确率: 66.65 %
# Epoch [50/200] 的训练集loss: 0.94
# Epoch [50/200] 的验证集准确率: 63.06 %
# Epoch [50/200] 的验证集loss: 1.04
# ------------------------------
# ------------------------------
# Epoch [51/200] 的训练集准确率: 67.88 %
# Epoch [51/200] 的训练集loss: 0.92
# Epoch [51/200] 的验证集准确率: 64.18 %
# Epoch [51/200] 的验证集loss: 1.01
# ------------------------------
# ------------------------------
# Epoch [52/200] 的训练集准确率: 68.33 %
# Epoch [52/200] 的训练集loss: 0.91
# Epoch [52/200] 的验证集准确率: 64.82 %
# Epoch [52/200] 的验证集loss: 1.00
# 发现更好的模型，已保存到 best_model.pth
# ------------------------------
# ------------------------------
# Epoch [53/200] 的训练集准确率: 69.23 %
# Epoch [53/200] 的训练集loss: 0.89
# Epoch [53/200] 的验证集准确率: 65.10 %
# Epoch [53/200] 的验证集loss: 0.99
# 发现更好的模型，已保存到 best_model.pth
# ------------------------------
# ------------------------------
# Epoch [54/200] 的训练集准确率: 68.29 %
# Epoch [54/200] 的训练集loss: 0.90
# Epoch [54/200] 的验证集准确率: 63.84 %
# Epoch [54/200] 的验证集loss: 1.01
# ------------------------------
# ------------------------------
# Epoch [55/200] 的训练集准确率: 69.40 %
# Epoch [55/200] 的训练集loss: 0.88
# Epoch [55/200] 的验证集准确率: 65.22 %
# Epoch [55/200] 的验证集loss: 0.99
# 发现更好的模型，已保存到 best_model.pth
# ------------------------------
# ------------------------------
# Epoch [56/200] 的训练集准确率: 69.06 %
# Epoch [56/200] 的训练集loss: 0.89
# Epoch [56/200] 的验证集准确率: 64.98 %
# Epoch [56/200] 的验证集loss: 1.00
# ------------------------------
# ------------------------------
# Epoch [57/200] 的训练集准确率: 69.49 %
# Epoch [57/200] 的训练集loss: 0.87
# Epoch [57/200] 的验证集准确率: 65.10 %
# Epoch [57/200] 的验证集loss: 0.99
# ------------------------------
# ------------------------------
# Epoch [58/200] 的训练集准确率: 70.30 %
# Epoch [58/200] 的训练集loss: 0.86
# Epoch [58/200] 的验证集准确率: 65.46 %
# Epoch [58/200] 的验证集loss: 0.97
# 发现更好的模型，已保存到 best_model.pth
# ------------------------------
# ------------------------------
# Epoch [59/200] 的训练集准确率: 67.74 %
# Epoch [59/200] 的训练集loss: 0.91
# Epoch [59/200] 的验证集准确率: 63.78 %
# Epoch [59/200] 的验证集loss: 1.03
# ------------------------------
# ------------------------------
# Epoch [60/200] 的训练集准确率: 70.62 %
# Epoch [60/200] 的训练集loss: 0.85
# Epoch [60/200] 的验证集准确率: 65.72 %
# Epoch [60/200] 的验证集loss: 0.97
# 发现更好的模型，已保存到 best_model.pth
# ------------------------------
# ------------------------------
# Epoch [61/200] 的训练集准确率: 70.36 %
# Epoch [61/200] 的训练集loss: 0.85
# Epoch [61/200] 的验证集准确率: 65.82 %
# Epoch [61/200] 的验证集loss: 0.98
# 发现更好的模型，已保存到 best_model.pth
# ------------------------------
# ------------------------------
# Epoch [62/200] 的训练集准确率: 70.79 %
# Epoch [62/200] 的训练集loss: 0.84
# Epoch [62/200] 的验证集准确率: 65.96 %
# Epoch [62/200] 的验证集loss: 0.97
# 发现更好的模型，已保存到 best_model.pth
# ------------------------------
# ------------------------------
# Epoch [63/200] 的训练集准确率: 69.99 %
# Epoch [63/200] 的训练集loss: 0.86
# Epoch [63/200] 的验证集准确率: 65.30 %
# Epoch [63/200] 的验证集loss: 0.99
# ------------------------------
# ------------------------------
# Epoch [64/200] 的训练集准确率: 70.72 %
# Epoch [64/200] 的训练集loss: 0.85
# Epoch [64/200] 的验证集准确率: 65.48 %
# Epoch [64/200] 的验证集loss: 0.98
# ------------------------------
# ------------------------------
# Epoch [65/200] 的训练集准确率: 69.92 %
# Epoch [65/200] 的训练集loss: 0.85
# Epoch [65/200] 的验证集准确率: 65.10 %
# Epoch [65/200] 的验证集loss: 0.98
# ------------------------------
# ------------------------------
# Epoch [66/200] 的训练集准确率: 70.91 %
# Epoch [66/200] 的训练集loss: 0.84
# Epoch [66/200] 的验证集准确率: 65.68 %
# Epoch [66/200] 的验证集loss: 0.97
# ------------------------------
# ------------------------------
# Epoch [67/200] 的训练集准确率: 71.84 %
# Epoch [67/200] 的训练集loss: 0.82
# Epoch [67/200] 的验证集准确率: 66.62 %
# Epoch [67/200] 的验证集loss: 0.96
# 发现更好的模型，已保存到 best_model.pth
# ------------------------------
# ------------------------------
# Epoch [68/200] 的训练集准确率: 70.72 %
# Epoch [68/200] 的训练集loss: 0.85
# Epoch [68/200] 的验证集准确率: 65.44 %
# Epoch [68/200] 的验证集loss: 0.99
# ------------------------------
# ------------------------------
# Epoch [69/200] 的训练集准确率: 71.52 %
# Epoch [69/200] 的训练集loss: 0.83
# Epoch [69/200] 的验证集准确率: 66.14 %
# Epoch [69/200] 的验证集loss: 0.97
# ------------------------------
# ------------------------------
# Epoch [70/200] 的训练集准确率: 71.41 %
# Epoch [70/200] 的训练集loss: 0.82
# Epoch [70/200] 的验证集准确率: 66.38 %
# Epoch [70/200] 的验证集loss: 0.97
# ------------------------------
# ------------------------------
# Epoch [71/200] 的训练集准确率: 71.52 %
# Epoch [71/200] 的训练集loss: 0.82
# Epoch [71/200] 的验证集准确率: 65.62 %
# Epoch [71/200] 的验证集loss: 0.98
# ------------------------------
# ------------------------------
# Epoch [72/200] 的训练集准确率: 71.61 %
# Epoch [72/200] 的训练集loss: 0.82
# Epoch [72/200] 的验证集准确率: 65.68 %
# Epoch [72/200] 的验证集loss: 0.97
# ------------------------------
# ------------------------------
# Epoch [73/200] 的训练集准确率: 71.78 %
# Epoch [73/200] 的训练集loss: 0.81
# Epoch [73/200] 的验证集准确率: 65.82 %
# Epoch [73/200] 的验证集loss: 0.97
# ------------------------------
# ------------------------------
# Epoch [74/200] 的训练集准确率: 71.20 %
# Epoch [74/200] 的训练集loss: 0.82
# Epoch [74/200] 的验证集准确率: 65.76 %
# Epoch [74/200] 的验证集loss: 0.98
# ------------------------------
# ------------------------------
# Epoch [75/200] 的训练集准确率: 73.12 %
# Epoch [75/200] 的训练集loss: 0.78
# Epoch [75/200] 的验证集准确率: 66.86 %
# Epoch [75/200] 的验证集loss: 0.95
# 发现更好的模型，已保存到 best_model.pth
# ------------------------------
# ------------------------------
# Epoch [76/200] 的训练集准确率: 73.32 %
# Epoch [76/200] 的训练集loss: 0.77
# Epoch [76/200] 的验证集准确率: 67.42 %
# Epoch [76/200] 的验证集loss: 0.94
# 发现更好的模型，已保存到 best_model.pth
# ------------------------------
# ------------------------------
# Epoch [77/200] 的训练集准确率: 72.82 %
# Epoch [77/200] 的训练集loss: 0.79
# Epoch [77/200] 的验证集准确率: 66.02 %
# Epoch [77/200] 的验证集loss: 0.95
# ------------------------------
# ------------------------------
# Epoch [78/200] 的训练集准确率: 72.52 %
# Epoch [78/200] 的训练集loss: 0.79
# Epoch [78/200] 的验证集准确率: 66.48 %
# Epoch [78/200] 的验证集loss: 0.96
# ------------------------------
# ------------------------------
# Epoch [79/200] 的训练集准确率: 72.93 %
# Epoch [79/200] 的训练集loss: 0.78
# Epoch [79/200] 的验证集准确率: 65.76 %
# Epoch [79/200] 的验证集loss: 0.96
# ------------------------------
# ------------------------------
# Epoch [80/200] 的训练集准确率: 74.20 %
# Epoch [80/200] 的训练集loss: 0.76
# Epoch [80/200] 的验证集准确率: 66.80 %
# Epoch [80/200] 的验证集loss: 0.94
# ------------------------------
# ------------------------------
# Epoch [81/200] 的训练集准确率: 74.08 %
# Epoch [81/200] 的训练集loss: 0.75
# Epoch [81/200] 的验证集准确率: 67.38 %
# Epoch [81/200] 的验证集loss: 0.93
# ------------------------------
# ------------------------------
# Epoch [82/200] 的训练集准确率: 73.61 %
# Epoch [82/200] 的训练集loss: 0.76
# Epoch [82/200] 的验证集准确率: 66.42 %
# Epoch [82/200] 的验证集loss: 0.95
# ------------------------------
# ------------------------------
# Epoch [83/200] 的训练集准确率: 74.10 %
# Epoch [83/200] 的训练集loss: 0.75
# Epoch [83/200] 的验证集准确率: 67.04 %
# Epoch [83/200] 的验证集loss: 0.94
# ------------------------------
# ------------------------------
# Epoch [84/200] 的训练集准确率: 75.29 %
# Epoch [84/200] 的训练集loss: 0.73
# Epoch [84/200] 的验证集准确率: 67.90 %
# Epoch [84/200] 的验证集loss: 0.92
# 发现更好的模型，已保存到 best_model.pth
# ------------------------------
# ------------------------------
# Epoch [85/200] 的训练集准确率: 73.89 %
# Epoch [85/200] 的训练集loss: 0.75
# Epoch [85/200] 的验证集准确率: 66.16 %
# Epoch [85/200] 的验证集loss: 0.95
# ------------------------------
# ------------------------------
# Epoch [86/200] 的训练集准确率: 74.69 %
# Epoch [86/200] 的训练集loss: 0.74
# Epoch [86/200] 的验证集准确率: 66.52 %
# Epoch [86/200] 的验证集loss: 0.94
# ------------------------------
# ------------------------------
# Epoch [87/200] 的训练集准确率: 75.07 %
# Epoch [87/200] 的训练集loss: 0.73
# Epoch [87/200] 的验证集准确率: 67.08 %
# Epoch [87/200] 的验证集loss: 0.93
# ------------------------------
# ------------------------------
# Epoch [88/200] 的训练集准确率: 75.81 %
# Epoch [88/200] 的训练集loss: 0.71
# Epoch [88/200] 的验证集准确率: 67.36 %
# Epoch [88/200] 的验证集loss: 0.92
# ------------------------------
# ------------------------------
# Epoch [89/200] 的训练集准确率: 73.86 %
# Epoch [89/200] 的训练集loss: 0.75
# Epoch [89/200] 的验证集准确率: 65.80 %
# Epoch [89/200] 的验证集loss: 0.97
# ------------------------------
# ------------------------------
# Epoch [90/200] 的训练集准确率: 75.40 %
# Epoch [90/200] 的训练集loss: 0.72
# Epoch [90/200] 的验证集准确率: 66.68 %
# Epoch [90/200] 的验证集loss: 0.94
# ------------------------------
# ------------------------------
# Epoch [91/200] 的训练集准确率: 74.81 %
# Epoch [91/200] 的训练集loss: 0.73
# Epoch [91/200] 的验证集准确率: 66.16 %
# Epoch [91/200] 的验证集loss: 0.96
# ------------------------------
# ------------------------------
# Epoch [92/200] 的训练集准确率: 75.25 %
# Epoch [92/200] 的训练集loss: 0.73
# Epoch [92/200] 的验证集准确率: 66.42 %
# Epoch [92/200] 的验证集loss: 0.95
# ------------------------------
# ------------------------------
# Epoch [93/200] 的训练集准确率: 76.09 %
# Epoch [93/200] 的训练集loss: 0.70
# Epoch [93/200] 的验证集准确率: 67.50 %
# Epoch [93/200] 的验证集loss: 0.93
# ------------------------------
# ------------------------------
# Epoch [94/200] 的训练集准确率: 75.52 %
# Epoch [94/200] 的训练集loss: 0.71
# Epoch [94/200] 的验证集准确率: 67.20 %
# Epoch [94/200] 的验证集loss: 0.94
# ------------------------------
# ------------------------------
# Epoch [95/200] 的训练集准确率: 75.28 %
# Epoch [95/200] 的训练集loss: 0.72
# Epoch [95/200] 的验证集准确率: 66.94 %
# Epoch [95/200] 的验证集loss: 0.95
# ------------------------------
# ------------------------------
# Epoch [96/200] 的训练集准确率: 75.99 %
# Epoch [96/200] 的训练集loss: 0.70
# Epoch [96/200] 的验证集准确率: 67.46 %
# Epoch [96/200] 的验证集loss: 0.93
# ------------------------------
# ------------------------------
# Epoch [97/200] 的训练集准确率: 76.00 %
# Epoch [97/200] 的训练集loss: 0.69
# Epoch [97/200] 的验证集准确率: 67.80 %
# Epoch [97/200] 的验证集loss: 0.93
# ------------------------------
# ------------------------------
# Epoch [98/200] 的训练集准确率: 75.10 %
# Epoch [98/200] 的训练集loss: 0.72
# Epoch [98/200] 的验证集准确率: 66.82 %
# Epoch [98/200] 的验证集loss: 0.97
# ------------------------------
# ------------------------------
# Epoch [99/200] 的训练集准确率: 77.15 %
# Epoch [99/200] 的训练集loss: 0.67
# Epoch [99/200] 的验证集准确率: 67.82 %
# Epoch [99/200] 的验证集loss: 0.93
# ------------------------------
# ------------------------------
# Epoch [100/200] 的训练集准确率: 75.44 %
# Epoch [100/200] 的训练集loss: 0.71
# Epoch [100/200] 的验证集准确率: 66.60 %
# Epoch [100/200] 的验证集loss: 0.96
# ------------------------------
# ------------------------------
# Epoch [101/200] 的训练集准确率: 77.58 %
# Epoch [101/200] 的训练集loss: 0.66
# Epoch [101/200] 的验证集准确率: 67.50 %
# Epoch [101/200] 的验证集loss: 0.92
# ------------------------------
# ------------------------------
# Epoch [102/200] 的训练集准确率: 77.04 %
# Epoch [102/200] 的训练集loss: 0.67
# Epoch [102/200] 的验证集准确率: 66.84 %
# Epoch [102/200] 的验证集loss: 0.94
# ------------------------------
# ------------------------------
# Epoch [103/200] 的训练集准确率: 75.81 %
# Epoch [103/200] 的训练集loss: 0.70
# Epoch [103/200] 的验证集准确率: 66.76 %
# Epoch [103/200] 的验证集loss: 0.96
# ------------------------------
# ------------------------------
# Epoch [104/200] 的训练集准确率: 76.78 %
# Epoch [104/200] 的训练集loss: 0.68
# Epoch [104/200] 的验证集准确率: 67.08 %
# Epoch [104/200] 的验证集loss: 0.94
# ------------------------------
# ------------------------------
# Epoch [105/200] 的训练集准确率: 77.86 %
# Epoch [105/200] 的训练集loss: 0.65
# Epoch [105/200] 的验证集准确率: 67.18 %
# Epoch [105/200] 的验证集loss: 0.93
# ------------------------------
# ------------------------------
# Epoch [106/200] 的训练集准确率: 77.66 %
# Epoch [106/200] 的训练集loss: 0.66
# Epoch [106/200] 的验证集准确率: 67.60 %
# Epoch [106/200] 的验证集loss: 0.93
# ------------------------------
# ------------------------------
# Epoch [107/200] 的训练集准确率: 76.33 %
# Epoch [107/200] 的训练集loss: 0.68
# Epoch [107/200] 的验证集准确率: 66.68 %
# Epoch [107/200] 的验证集loss: 0.96
# ------------------------------
# ------------------------------
# Epoch [108/200] 的训练集准确率: 78.62 %
# Epoch [108/200] 的训练集loss: 0.64
# Epoch [108/200] 的验证集准确率: 67.46 %
# Epoch [108/200] 的验证集loss: 0.93
# ------------------------------
# ------------------------------
# Epoch [109/200] 的训练集准确率: 77.84 %
# Epoch [109/200] 的训练集loss: 0.65
# Epoch [109/200] 的验证集准确率: 67.12 %
# Epoch [109/200] 的验证集loss: 0.94
# ------------------------------
# ------------------------------
# Epoch [110/200] 的训练集准确率: 78.44 %
# Epoch [110/200] 的训练集loss: 0.64
# Epoch [110/200] 的验证集准确率: 67.98 %
# Epoch [110/200] 的验证集loss: 0.93
# 发现更好的模型，已保存到 best_model.pth
# ------------------------------
# ------------------------------
# Epoch [111/200] 的训练集准确率: 78.32 %
# Epoch [111/200] 的训练集loss: 0.64
# Epoch [111/200] 的验证集准确率: 67.24 %
# Epoch [111/200] 的验证集loss: 0.94
# ------------------------------
# ------------------------------
# Epoch [112/200] 的训练集准确率: 78.32 %
# Epoch [112/200] 的训练集loss: 0.64
# Epoch [112/200] 的验证集准确率: 67.22 %
# Epoch [112/200] 的验证集loss: 0.95
# ------------------------------
# ------------------------------
# Epoch [113/200] 的训练集准确率: 78.57 %
# Epoch [113/200] 的训练集loss: 0.63
# Epoch [113/200] 的验证集准确率: 67.40 %
# Epoch [113/200] 的验证集loss: 0.94
# ------------------------------
# ------------------------------
# Epoch [114/200] 的训练集准确率: 77.68 %
# Epoch [114/200] 的训练集loss: 0.64
# Epoch [114/200] 的验证集准确率: 67.08 %
# Epoch [114/200] 的验证集loss: 0.96
# ------------------------------
# ------------------------------
# Epoch [115/200] 的训练集准确率: 77.13 %
# Epoch [115/200] 的训练集loss: 0.66
# Epoch [115/200] 的验证集准确率: 66.70 %
# Epoch [115/200] 的验证集loss: 0.97
# ------------------------------
# ------------------------------
# Epoch [116/200] 的训练集准确率: 77.82 %
# Epoch [116/200] 的训练集loss: 0.65
# Epoch [116/200] 的验证集准确率: 66.34 %
# Epoch [116/200] 的验证集loss: 0.96
# ------------------------------
# ------------------------------
# Epoch [117/200] 的训练集准确率: 78.92 %
# Epoch [117/200] 的训练集loss: 0.62
# Epoch [117/200] 的验证集准确率: 67.04 %
# Epoch [117/200] 的验证集loss: 0.94
# ------------------------------
# ------------------------------
# Epoch [118/200] 的训练集准确率: 78.96 %
# Epoch [118/200] 的训练集loss: 0.61
# Epoch [118/200] 的验证集准确率: 67.02 %
# Epoch [118/200] 的验证集loss: 0.95
# ------------------------------
# ------------------------------
# Epoch [119/200] 的训练集准确率: 79.34 %
# Epoch [119/200] 的训练集loss: 0.61
# Epoch [119/200] 的验证集准确率: 67.48 %
# Epoch [119/200] 的验证集loss: 0.95
# ------------------------------
# ------------------------------
# Epoch [120/200] 的训练集准确率: 79.21 %
# Epoch [120/200] 的训练集loss: 0.61
# Epoch [120/200] 的验证集准确率: 67.14 %
# Epoch [120/200] 的验证集loss: 0.95
# ------------------------------
# ------------------------------
# Epoch [121/200] 的训练集准确率: 78.79 %
# Epoch [121/200] 的训练集loss: 0.63
# Epoch [121/200] 的验证集准确率: 66.78 %
# Epoch [121/200] 的验证集loss: 0.97
# ------------------------------
# ------------------------------
# Epoch [122/200] 的训练集准确率: 80.20 %
# Epoch [122/200] 的训练集loss: 0.59
# Epoch [122/200] 的验证集准确率: 67.48 %
# Epoch [122/200] 的验证集loss: 0.94
# ------------------------------
# ------------------------------
# Epoch [123/200] 的训练集准确率: 79.58 %
# Epoch [123/200] 的训练集loss: 0.60
# Epoch [123/200] 的验证集准确率: 67.34 %
# Epoch [123/200] 的验证集loss: 0.95
# ------------------------------
# ------------------------------
# Epoch [124/200] 的训练集准确率: 80.38 %
# Epoch [124/200] 的训练集loss: 0.58
# Epoch [124/200] 的验证集准确率: 67.16 %
# Epoch [124/200] 的验证集loss: 0.95
# ------------------------------
# ------------------------------
# Epoch [125/200] 的训练集准确率: 79.93 %
# Epoch [125/200] 的训练集loss: 0.59
# Epoch [125/200] 的验证集准确率: 67.40 %
# Epoch [125/200] 的验证集loss: 0.95
# ------------------------------
# ------------------------------
# Epoch [126/200] 的训练集准确率: 78.86 %
# Epoch [126/200] 的训练集loss: 0.61
# Epoch [126/200] 的验证集准确率: 66.62 %
# Epoch [126/200] 的验证集loss: 0.98
# ------------------------------
# ------------------------------
# Epoch [127/200] 的训练集准确率: 79.21 %
# Epoch [127/200] 的训练集loss: 0.61
# Epoch [127/200] 的验证集准确率: 66.98 %
# Epoch [127/200] 的验证集loss: 0.97
# ------------------------------
# ------------------------------
# Epoch [128/200] 的训练集准确率: 79.98 %
# Epoch [128/200] 的训练集loss: 0.59
# Epoch [128/200] 的验证集准确率: 66.28 %
# Epoch [128/200] 的验证集loss: 0.96
# ------------------------------
# ------------------------------
# Epoch [129/200] 的训练集准确率: 81.48 %
# Epoch [129/200] 的训练集loss: 0.56
# Epoch [129/200] 的验证集准确率: 67.64 %
# Epoch [129/200] 的验证集loss: 0.94
# ------------------------------
# ------------------------------
# Epoch [130/200] 的训练集准确率: 81.50 %
# Epoch [130/200] 的训练集loss: 0.56
# Epoch [130/200] 的验证集准确率: 67.30 %
# Epoch [130/200] 的验证集loss: 0.95
# ------------------------------
# ------------------------------
# Epoch [131/200] 的训练集准确率: 80.00 %
# Epoch [131/200] 的训练集loss: 0.59
# Epoch [131/200] 的验证集准确率: 66.96 %
# Epoch [131/200] 的验证集loss: 0.97
# ------------------------------
# ------------------------------
# Epoch [132/200] 的训练集准确率: 78.89 %
# Epoch [132/200] 的训练集loss: 0.61
# Epoch [132/200] 的验证集准确率: 66.06 %
# Epoch [132/200] 的验证集loss: 0.98
# ------------------------------
# ------------------------------
# Epoch [133/200] 的训练集准确率: 80.30 %
# Epoch [133/200] 的训练集loss: 0.58
# Epoch [133/200] 的验证集准确率: 66.88 %
# Epoch [133/200] 的验证集loss: 0.97
# ------------------------------
# ------------------------------
# Epoch [134/200] 的训练集准确率: 81.40 %
# Epoch [134/200] 的训练集loss: 0.55
# Epoch [134/200] 的验证集准确率: 67.44 %
# Epoch [134/200] 的验证集loss: 0.96
# ------------------------------
# ------------------------------
# Epoch [135/200] 的训练集准确率: 81.51 %
# Epoch [135/200] 的训练集loss: 0.56
# Epoch [135/200] 的验证集准确率: 67.18 %
# Epoch [135/200] 的验证集loss: 0.96
# ------------------------------
# ------------------------------
# Epoch [136/200] 的训练集准确率: 80.17 %
# Epoch [136/200] 的训练集loss: 0.58
# Epoch [136/200] 的验证集准确率: 67.02 %
# Epoch [136/200] 的验证集loss: 0.99
# ------------------------------
# ------------------------------
# Epoch [137/200] 的训练集准确率: 82.41 %
# Epoch [137/200] 的训练集loss: 0.53
# Epoch [137/200] 的验证集准确率: 67.56 %
# Epoch [137/200] 的验证集loss: 0.94
# ------------------------------
# ------------------------------
# Epoch [138/200] 的训练集准确率: 81.30 %
# Epoch [138/200] 的训练集loss: 0.55
# Epoch [138/200] 的验证集准确率: 67.34 %
# Epoch [138/200] 的验证集loss: 0.97
# ------------------------------
# ------------------------------
# Epoch [139/200] 的训练集准确率: 81.86 %
# Epoch [139/200] 的训练集loss: 0.54
# Epoch [139/200] 的验证集准确率: 67.44 %
# Epoch [139/200] 的验证集loss: 0.96
# ------------------------------
# ------------------------------
# Epoch [140/200] 的训练集准确率: 82.48 %
# Epoch [140/200] 的训练集loss: 0.52
# Epoch [140/200] 的验证集准确率: 68.12 %
# Epoch [140/200] 的验证集loss: 0.95
# 发现更好的模型，已保存到 best_model.pth
# ------------------------------
# ------------------------------
# Epoch [141/200] 的训练集准确率: 81.59 %
# Epoch [141/200] 的训练集loss: 0.54
# Epoch [141/200] 的验证集准确率: 67.40 %
# Epoch [141/200] 的验证集loss: 0.96
# ------------------------------
# ------------------------------
# Epoch [142/200] 的训练集准确率: 81.06 %
# Epoch [142/200] 的训练集loss: 0.55
# Epoch [142/200] 的验证集准确率: 66.78 %
# Epoch [142/200] 的验证集loss: 0.99
# ------------------------------
# ------------------------------
# Epoch [143/200] 的训练集准确率: 82.27 %
# Epoch [143/200] 的训练集loss: 0.53
# Epoch [143/200] 的验证集准确率: 66.92 %
# Epoch [143/200] 的验证集loss: 0.98
# ------------------------------
# ------------------------------
# Epoch [144/200] 的训练集准确率: 83.24 %
# Epoch [144/200] 的训练集loss: 0.51
# Epoch [144/200] 的验证集准确率: 67.32 %
# Epoch [144/200] 的验证集loss: 0.96
# ------------------------------
# ------------------------------
# Epoch [145/200] 的训练集准确率: 82.07 %
# Epoch [145/200] 的训练集loss: 0.53
# Epoch [145/200] 的验证集准确率: 66.96 %
# Epoch [145/200] 的验证集loss: 0.99
# ------------------------------
# ------------------------------
# Epoch [146/200] 的训练集准确率: 80.75 %
# Epoch [146/200] 的训练集loss: 0.55
# Epoch [146/200] 的验证集准确率: 66.32 %
# Epoch [146/200] 的验证集loss: 1.00
# ------------------------------
# ------------------------------
# Epoch [147/200] 的训练集准确率: 81.15 %
# Epoch [147/200] 的训练集loss: 0.55
# Epoch [147/200] 的验证集准确率: 66.68 %
# Epoch [147/200] 的验证集loss: 1.00
# ------------------------------
# ------------------------------
# Epoch [148/200] 的训练集准确率: 82.07 %
# Epoch [148/200] 的训练集loss: 0.53
# Epoch [148/200] 的验证集准确率: 67.02 %
# Epoch [148/200] 的验证集loss: 0.99
# ------------------------------
# ------------------------------
# Epoch [149/200] 的训练集准确率: 83.69 %
# Epoch [149/200] 的训练集loss: 0.50
# Epoch [149/200] 的验证集准确率: 67.66 %
# Epoch [149/200] 的验证集loss: 0.96
# ------------------------------
# ------------------------------
# Epoch [150/200] 的训练集准确率: 84.47 %
# Epoch [150/200] 的训练集loss: 0.48
# Epoch [150/200] 的验证集准确率: 68.06 %
# Epoch [150/200] 的验证集loss: 0.96
# ------------------------------
# ------------------------------
# Epoch [151/200] 的训练集准确率: 81.78 %
# Epoch [151/200] 的训练集loss: 0.54
# Epoch [151/200] 的验证集准确率: 66.68 %
# Epoch [151/200] 的验证集loss: 1.01
# ------------------------------
# ------------------------------
# Epoch [152/200] 的训练集准确率: 83.85 %
# Epoch [152/200] 的训练集loss: 0.49
# Epoch [152/200] 的验证集准确率: 67.48 %
# Epoch [152/200] 的验证集loss: 0.97
# ------------------------------
# ------------------------------
# Epoch [153/200] 的训练集准确率: 83.02 %
# Epoch [153/200] 的训练集loss: 0.51
# Epoch [153/200] 的验证集准确率: 67.00 %
# Epoch [153/200] 的验证集loss: 0.99
# ------------------------------
# ------------------------------
# Epoch [154/200] 的训练集准确率: 81.34 %
# Epoch [154/200] 的训练集loss: 0.55
# Epoch [154/200] 的验证集准确率: 66.24 %
# Epoch [154/200] 的验证集loss: 1.03
# ------------------------------
# ------------------------------
# Epoch [155/200] 的训练集准确率: 82.50 %
# Epoch [155/200] 的训练集loss: 0.52
# Epoch [155/200] 的验证集准确率: 66.86 %
# Epoch [155/200] 的验证集loss: 1.00
# ------------------------------
# ------------------------------
# Epoch [156/200] 的训练集准确率: 82.46 %
# Epoch [156/200] 的训练集loss: 0.52
# Epoch [156/200] 的验证集准确率: 67.06 %
# Epoch [156/200] 的验证集loss: 1.00
# ------------------------------
# ------------------------------
# Epoch [157/200] 的训练集准确率: 84.76 %
# Epoch [157/200] 的训练集loss: 0.47
# Epoch [157/200] 的验证集准确率: 67.64 %
# Epoch [157/200] 的验证集loss: 0.97
# ------------------------------
# ------------------------------
# Epoch [158/200] 的训练集准确率: 83.52 %
# Epoch [158/200] 的训练集loss: 0.49
# Epoch [158/200] 的验证集准确率: 67.00 %
# Epoch [158/200] 的验证集loss: 1.00
# ------------------------------
# ------------------------------
# Epoch [159/200] 的训练集准确率: 84.18 %
# Epoch [159/200] 的训练集loss: 0.48
# Epoch [159/200] 的验证集准确率: 67.42 %
# Epoch [159/200] 的验证集loss: 0.99
# ------------------------------
# ------------------------------
# Epoch [160/200] 的训练集准确率: 85.22 %
# Epoch [160/200] 的训练集loss: 0.46
# Epoch [160/200] 的验证集准确率: 67.86 %
# Epoch [160/200] 的验证集loss: 0.97
# ------------------------------
# ------------------------------
# Epoch [161/200] 的训练集准确率: 83.76 %
# Epoch [161/200] 的训练集loss: 0.48
# Epoch [161/200] 的验证集准确率: 67.50 %
# Epoch [161/200] 的验证集loss: 1.01
# ------------------------------
# ------------------------------
# Epoch [162/200] 的训练集准确率: 85.00 %
# Epoch [162/200] 的训练集loss: 0.46
# Epoch [162/200] 的验证集准确率: 67.12 %
# Epoch [162/200] 的验证集loss: 0.99
# ------------------------------
# ------------------------------
# Epoch [163/200] 的训练集准确率: 85.15 %
# Epoch [163/200] 的训练集loss: 0.46
# Epoch [163/200] 的验证集准确率: 67.42 %
# Epoch [163/200] 的验证集loss: 0.99
# ------------------------------
# ------------------------------
# Epoch [164/200] 的训练集准确率: 85.17 %
# Epoch [164/200] 的训练集loss: 0.46
# Epoch [164/200] 的验证集准确率: 67.66 %
# Epoch [164/200] 的验证集loss: 0.98
# ------------------------------
# ------------------------------
# Epoch [165/200] 的训练集准确率: 84.47 %
# Epoch [165/200] 的训练集loss: 0.47
# Epoch [165/200] 的验证集准确率: 67.12 %
# Epoch [165/200] 的验证集loss: 1.01
# ------------------------------
# ------------------------------
# Epoch [166/200] 的训练集准确率: 84.40 %
# Epoch [166/200] 的训练集loss: 0.47
# Epoch [166/200] 的验证集准确率: 67.18 %
# Epoch [166/200] 的验证集loss: 1.02
# ------------------------------
# ------------------------------
# Epoch [167/200] 的训练集准确率: 86.67 %
# Epoch [167/200] 的训练集loss: 0.43
# Epoch [167/200] 的验证集准确率: 67.68 %
# Epoch [167/200] 的验证集loss: 0.98
# ------------------------------
# ------------------------------
# Epoch [168/200] 的训练集准确率: 86.35 %
# Epoch [168/200] 的训练集loss: 0.43
# Epoch [168/200] 的验证集准确率: 67.18 %
# Epoch [168/200] 的验证集loss: 0.99
# ------------------------------
# ------------------------------
# Epoch [169/200] 的训练集准确率: 85.92 %
# Epoch [169/200] 的训练集loss: 0.44
# Epoch [169/200] 的验证集准确率: 67.76 %
# Epoch [169/200] 的验证集loss: 1.00
# ------------------------------
# ------------------------------
# Epoch [170/200] 的训练集准确率: 85.73 %
# Epoch [170/200] 的训练集loss: 0.44
# Epoch [170/200] 的验证集准确率: 67.46 %
# Epoch [170/200] 的验证集loss: 1.01
# ------------------------------
# ------------------------------
# Epoch [171/200] 的训练集准确率: 83.77 %
# Epoch [171/200] 的训练集loss: 0.47
# Epoch [171/200] 的验证集准确率: 66.44 %
# Epoch [171/200] 的验证集loss: 1.04
# ------------------------------
# ------------------------------
# Epoch [172/200] 的训练集准确率: 85.11 %
# Epoch [172/200] 的训练集loss: 0.45
# Epoch [172/200] 的验证集准确率: 66.28 %
# Epoch [172/200] 的验证集loss: 1.02
# ------------------------------
# ------------------------------
# Epoch [173/200] 的训练集准确率: 85.47 %
# Epoch [173/200] 的训练集loss: 0.44
# Epoch [173/200] 的验证集准确率: 67.04 %
# Epoch [173/200] 的验证集loss: 1.02
# ------------------------------
# ------------------------------
# Epoch [174/200] 的训练集准确率: 86.20 %
# Epoch [174/200] 的训练集loss: 0.43
# Epoch [174/200] 的验证集准确率: 67.40 %
# Epoch [174/200] 的验证集loss: 1.00
# ------------------------------
# ------------------------------
# Epoch [175/200] 的训练集准确率: 85.99 %
# Epoch [175/200] 的训练集loss: 0.43
# Epoch [175/200] 的验证集准确率: 67.18 %
# Epoch [175/200] 的验证集loss: 1.02
# ------------------------------
# ------------------------------
# Epoch [176/200] 的训练集准确率: 86.74 %
# Epoch [176/200] 的训练集loss: 0.42
# Epoch [176/200] 的验证集准确率: 67.28 %
# Epoch [176/200] 的验证集loss: 1.01
# ------------------------------
# ------------------------------
# Epoch [177/200] 的训练集准确率: 87.76 %
# Epoch [177/200] 的训练集loss: 0.40
# Epoch [177/200] 的验证集准确率: 67.30 %
# Epoch [177/200] 的验证集loss: 1.00
# ------------------------------
# ------------------------------
# Epoch [178/200] 的训练集准确率: 86.71 %
# Epoch [178/200] 的训练集loss: 0.41
# Epoch [178/200] 的验证集准确率: 67.50 %
# Epoch [178/200] 的验证集loss: 1.01
# ------------------------------
# ------------------------------
# Epoch [179/200] 的训练集准确率: 86.30 %
# Epoch [179/200] 的训练集loss: 0.42
# Epoch [179/200] 的验证集准确率: 66.94 %
# Epoch [179/200] 的验证集loss: 1.03
# ------------------------------
# ------------------------------
# Epoch [180/200] 的训练集准确率: 86.68 %
# Epoch [180/200] 的训练集loss: 0.41
# Epoch [180/200] 的验证集准确率: 67.40 %
# Epoch [180/200] 的验证集loss: 1.01
# ------------------------------
# ------------------------------
# Epoch [181/200] 的训练集准确率: 86.58 %
# Epoch [181/200] 的训练集loss: 0.41
# Epoch [181/200] 的验证集准确率: 67.16 %
# Epoch [181/200] 的验证集loss: 1.04
# ------------------------------
# ------------------------------
# Epoch [182/200] 的训练集准确率: 86.92 %
# Epoch [182/200] 的训练集loss: 0.41
# Epoch [182/200] 的验证集准确率: 67.08 %
# Epoch [182/200] 的验证集loss: 1.03
# ------------------------------
# ------------------------------
# Epoch [183/200] 的训练集准确率: 87.09 %
# Epoch [183/200] 的训练集loss: 0.41
# Epoch [183/200] 的验证集准确率: 67.36 %
# Epoch [183/200] 的验证集loss: 1.03
# ------------------------------
# ------------------------------
# Epoch [184/200] 的训练集准确率: 86.78 %
# Epoch [184/200] 的训练集loss: 0.41
# Epoch [184/200] 的验证集准确率: 67.12 %
# Epoch [184/200] 的验证集loss: 1.03
# ------------------------------
# ------------------------------
# Epoch [185/200] 的训练集准确率: 87.39 %
# Epoch [185/200] 的训练集loss: 0.40
# Epoch [185/200] 的验证集准确率: 67.24 %
# Epoch [185/200] 的验证集loss: 1.03
# ------------------------------
# ------------------------------
# Epoch [186/200] 的训练集准确率: 87.79 %
# Epoch [186/200] 的训练集loss: 0.39
# Epoch [186/200] 的验证集准确率: 67.34 %
# Epoch [186/200] 的验证集loss: 1.03
# ------------------------------
# ------------------------------
# Epoch [187/200] 的训练集准确率: 86.08 %
# Epoch [187/200] 的训练集loss: 0.41
# Epoch [187/200] 的验证集准确率: 67.04 %
# Epoch [187/200] 的验证集loss: 1.05
# ------------------------------
# ------------------------------
# Epoch [188/200] 的训练集准确率: 86.63 %
# Epoch [188/200] 的训练集loss: 0.40
# Epoch [188/200] 的验证集准确率: 66.88 %
# Epoch [188/200] 的验证集loss: 1.05
# ------------------------------
# ------------------------------
# Epoch [189/200] 的训练集准确率: 86.69 %
# Epoch [189/200] 的训练集loss: 0.41
# Epoch [189/200] 的验证集准确率: 66.70 %
# Epoch [189/200] 的验证集loss: 1.07
# ------------------------------
# ------------------------------
# Epoch [190/200] 的训练集准确率: 87.64 %
# Epoch [190/200] 的训练集loss: 0.38
# Epoch [190/200] 的验证集准确率: 66.96 %
# Epoch [190/200] 的验证集loss: 1.05
# ------------------------------
# ------------------------------
# Epoch [191/200] 的训练集准确率: 87.80 %
# Epoch [191/200] 的训练集loss: 0.38
# Epoch [191/200] 的验证集准确率: 67.66 %
# Epoch [191/200] 的验证集loss: 1.04
# ------------------------------
# ------------------------------
# Epoch [192/200] 的训练集准确率: 87.62 %
# Epoch [192/200] 的训练集loss: 0.38
# Epoch [192/200] 的验证集准确率: 67.54 %
# Epoch [192/200] 的验证集loss: 1.05
# ------------------------------
# ------------------------------
# Epoch [193/200] 的训练集准确率: 88.11 %
# Epoch [193/200] 的训练集loss: 0.37
# Epoch [193/200] 的验证集准确率: 67.04 %
# Epoch [193/200] 的验证集loss: 1.05
# ------------------------------
# ------------------------------
# Epoch [194/200] 的训练集准确率: 87.88 %
# Epoch [194/200] 的训练集loss: 0.38
# Epoch [194/200] 的验证集准确率: 66.82 %
# Epoch [194/200] 的验证集loss: 1.07
# ------------------------------
# ------------------------------
# Epoch [195/200] 的训练集准确率: 87.29 %
# Epoch [195/200] 的训练集loss: 0.39
# Epoch [195/200] 的验证集准确率: 66.68 %
# Epoch [195/200] 的验证集loss: 1.07
# ------------------------------
# ------------------------------
# Epoch [196/200] 的训练集准确率: 87.22 %
# Epoch [196/200] 的训练集loss: 0.39
# Epoch [196/200] 的验证集准确率: 66.52 %
# Epoch [196/200] 的验证集loss: 1.06
# ------------------------------
# ------------------------------
# Epoch [197/200] 的训练集准确率: 88.70 %
# Epoch [197/200] 的训练集loss: 0.36
# Epoch [197/200] 的验证集准确率: 67.72 %
# Epoch [197/200] 的验证集loss: 1.06
# ------------------------------
# ------------------------------
# Epoch [198/200] 的训练集准确率: 89.38 %
# Epoch [198/200] 的训练集loss: 0.35
# Epoch [198/200] 的验证集准确率: 67.50 %
# Epoch [198/200] 的验证集loss: 1.05
# ------------------------------
# ------------------------------
# Epoch [199/200] 的训练集准确率: 88.72 %
# Epoch [199/200] 的训练集loss: 0.36
# Epoch [199/200] 的验证集准确率: 67.54 %
# Epoch [199/200] 的验证集loss: 1.07
# ------------------------------
# ------------------------------
# Epoch [200/200] 的训练集准确率: 88.19 %
# Epoch [200/200] 的训练集loss: 0.37
# Epoch [200/200] 的验证集准确率: 66.90 %
# Epoch [200/200] 的验证集loss: 1.07
# ------------------------------
# 加载最佳模型 (best_model.pth) 进行最终测试...
# 测试集准确率: 67.79 %
# 测试集loss: 0.98 %
