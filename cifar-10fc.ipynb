# %% [markdown]
# ## 准备数据

# %%
import torch
import torch.nn as nn
import torch.utils.data as data
import torch.optim as optim
import torch.nn.functional as F
import numpy as np
import pickle
from sklearn.model_selection import train_test_split
from torch.utils.tensorboard import SummaryWriter

def unpickle(file):
    with open(file, 'rb') as fo:
        dict = pickle.load(fo, encoding='latin1')
    return dict

cifar10_dir = '/home/lc/d2l-zh/exercise/cifar-10-python/cifar-10-batches-py/'
all_train_data = []
all_train_labels = []

for i in range(1, 6):
    file_path = f'{cifar10_dir}/data_batch_{i}'
    data_dict = unpickle(file_path)
    all_train_data.append(data_dict['data'])
    all_train_labels.extend(data_dict['labels'])

train_data_np = np.concatenate(all_train_data)
train_labels_np = np.array(all_train_labels)

X_train, X_val, y_train, y_val = train_test_split(
    train_data_np, 
    train_labels_np, 
    test_size=0.1, 
    random_state=42,
    stratify=train_labels_np 
)

test_file_path = f'{cifar10_dir}/test_batch'
test_dict = unpickle(test_file_path)
X_test = test_dict['data']
y_test = np.array(test_dict['labels'])

print(f"测试数据 (X_test) 形状: {X_test.shape}")
print(f"测试标签 (y_test) 形状: {y_test.shape}")

print(f"原始训练数据形状: {train_data_np.shape}")
print("-" * 30)
print(f"划分后的训练数据 (X_train) 形状: {X_train.shape}")
print(f"划分后的训练标签 (y_train) 形状: {y_train.shape}")
print(f"划分后的验证数据 (X_val) 形状: {X_val.shape}")
print(f"划分后的验证标签 (y_val) 形状: {y_val.shape}")
# Out:
# 测试数据 (X_test) 形状: (10000, 3072)
# 测试标签 (y_test) 形状: (10000,)
# 原始训练数据形状: (50000, 3072)
# ------------------------------
# 划分后的训练数据 (X_train) 形状: (45000, 3072)
# 划分后的训练标签 (y_train) 形状: (45000,)
# 划分后的验证数据 (X_val) 形状: (5000, 3072)
# 划分后的验证标签 (y_val) 形状: (5000,)

# %%
class SimpleCIFAR10Dataset(data.Dataset):
    """
    一个极简的自定义数据集类。
    它直接接收NumPy数据，并在需要时返回PyTorch张量。
    """
    def __init__(self, images, labels):
        """
        初始化函数。
        Args:
            images (numpy.ndarray): 图像数据，形状为 (样本数, 3072)，代表一维形式。
            labels (numpy.ndarray): 标签数据，形状为 (样本数,)。
        """
        # 将数据转换为 PyTorch Tensor。这是与 PyTorch 模型交互的必要步骤。
        # 图像数据需要是浮点型以供模型计算。
        self.images = torch.from_numpy(images / 255.0).float()
        # 标签在计算损失函数时通常需要是长整型 (LongTensor)。
        self.labels = torch.from_numpy(labels).long()

    def __len__(self):
        """返回数据集的样本总数。"""
        return len(self.labels)

    def __getitem__(self, idx):
        """根据索引获取一个样本（图像和标签）。"""
        return self.images[idx], self.labels[idx]

# 1. 实例化训练和验证数据集
train_dataset = SimpleCIFAR10Dataset(X_train, y_train)
val_dataset = SimpleCIFAR10Dataset(X_val, y_val)
test_dataset = SimpleCIFAR10Dataset(X_test, y_test)

# 2. 创建 DataLoader
batch_size = 2000  # 定义每个批次的大小

train_loader = data.DataLoader(
    dataset=train_dataset,
    batch_size=batch_size,
    shuffle=True,  # 训练时打乱数据顺序以增强模型泛化能力
    num_workers=16, # 增加工作进程数
    pin_memory=True
)

val_loader = data.DataLoader(
    dataset=val_dataset,
    batch_size=batch_size,
    shuffle=False, # 验证时通常不需要打乱
    num_workers=16, # 增加工作进程数
    pin_memory=True
)

test_loader = data.DataLoader(
    dataset=test_dataset,
    batch_size=batch_size, # 可以和训练时用一样的batch_size
    shuffle=False,      # 测试时不需要打乱数据
    num_workers=16, # 增加工作进程数
    pin_memory=True
)

# 3. 验证 DataLoader 是否工作正常
print("成功创建最简化的 DataLoader！")
print("-" * 30)

# 从 train_loader 中获取一个批次的数据进行检查
data_batch, labels_batch = next(iter(train_loader))
print(f"一个训练批次的数据 (images) 形状: {data_batch.shape}")
print(f"一个训练批次的标签 (labels) 形状: {labels_batch.shape}")
print(f"批次数据的类型: {data_batch.dtype}")
print(f"批次标签的类型: {labels_batch.dtype}")
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
# Out:
# 成功创建最简化的 DataLoader！
# ------------------------------
# 一个训练批次的数据 (images) 形状: torch.Size([2000, 3072])
# 一个训练批次的标签 (labels) 形状: torch.Size([2000])
# 批次数据的类型: torch.float32
# 批次标签的类型: torch.int64
# Using device: cuda

# %% [markdown]
# ## 建立模型

# %%
class myModel(nn.Module):
    def __init__(self):
        super(myModel,self).__init__()
        self.linear1 = nn.Linear(3072,2048)
        self.linear2 = nn.Linear(2048,1024)
        self.linear3 = nn.Linear(1024,512)
        self.linear4 = nn.Linear(512,64)
        self.linear5 = nn.Linear(64,10)
        self.dropout = nn.Dropout(p=0.3)
    def forward(self, inp):
        x = self.linear1(inp)
        x = torch.relu(x)
        x = self.dropout(x)
        x = self.linear2(x)
        x = torch.relu(x)
        x = self.dropout(x)
        x = self.linear3(x)
        x = torch.relu(x)
        x = self.dropout(x)
        x = self.linear4(x)
        x = torch.relu(x)
        x = self.dropout(x)
        logits = self.linear5(x)
        return logits
        
model = myModel()

optimizer = optim.Adam(model.parameters(),lr = 1e-5, weight_decay=1e-4)
# optimizer = optim.Adam(model.parameters(),lr = 0.001)

def eval_model(model, test_loader, criterion):
    """
    在测试集上评估模型的最终性能。
    """
    model.eval()  # 切换到评估模式
    test_loss = 0.0
    correct = 0
    total = 0
    with torch.no_grad(): # 在此模式下，所有计算都不会被记录用于反向传播
        for images, labels in test_loader:
            images = images.to(device)
            labels = labels.to(device)
            outputs = model(images)
            loss = criterion(outputs, labels)
            test_loss += loss.item()

            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

    # 计算平均损失和准确率
    avg_loss = test_loss / len(test_loader)
    accuracy = 100 * correct / total

    return accuracy, avg_loss

# %% [markdown]
# ## 计算 loss

# %%
criterion = nn.CrossEntropyLoss()

# %% [markdown]
# ## 实际训练

# %%
num_epochs = 200
def train_one_step(model,optimizer,train_loader):
    model.train()
    for x_batch,y_batch in train_loader:
        x_batch = x_batch.to(device)
        y_batch = y_batch.to(device)
        optimizer.zero_grad()
        logits = model(x_batch)
        loss =  criterion(logits,y_batch)
        loss.backward()
        optimizer.step()

if __name__ == '__main__':
    model.to(device)
    writer = SummaryWriter('./logs')
    writer.add_graph(model, torch.randn(1, 3072).to(device))
    best_val_accuracy = 0.0
    best_model_path = "best_model.pth"
    for i in range(num_epochs):
        train_one_step(model,optimizer,train_loader)
        train_accuracy, train_loss = eval_model(model, train_loader, criterion)
        val_accuracy, val_loss = eval_model(model, val_loader, criterion)
        writer.add_scalar('Accuracy/Train_Accuracy', train_accuracy, i)
        writer.add_scalar('Accuracy/Validation_Accuracy', val_accuracy, i)
        writer.add_scalar('Loss/Validation_Loss', train_loss, i)
        writer.add_scalar('Loss/Train_Loss', val_loss, i)
        print("-" * 30)
        print(f'Epoch [{i+1}/{num_epochs}] 的训练集准确率: {train_accuracy:.2f} %')
        print(f'Epoch [{i+1}/{num_epochs}] 的训练集loss: {train_loss:.2f}')
        print(f'Epoch [{i+1}/{num_epochs}] 的验证集准确率: {val_accuracy:.2f} %')
        print(f'Epoch [{i+1}/{num_epochs}] 的验证集loss: {val_loss:.2f}')
        if val_accuracy > best_val_accuracy:
            best_val_accuracy = val_accuracy
            torch.save(model.state_dict(), best_model_path)
            print(f"发现更好的模型，已保存到 {best_model_path}")
        print("-" * 30)
    print(f"加载最佳模型 ({best_model_path}) 进行最终测试...")
    model.load_state_dict(torch.load(best_model_path))

    # 使用加载了最佳权重的模型进行测试
    test_accuracy, test_loss = eval_model(model, test_loader, criterion)
    print(f'测试集准确率: {test_accuracy:.2f} %')
    print(f'测试集loss: {test_loss:.2f} %')
    writer.close()
# Out:
# ------------------------------
# Epoch [1/200] 的训练集准确率: 13.76 %
# Epoch [1/200] 的训练集loss: 2.30
# Epoch [1/200] 的验证集准确率: 14.08 %
# Epoch [1/200] 的验证集loss: 2.30
# 发现更好的模型，已保存到 best_model.pth
# ------------------------------
# ------------------------------
# Epoch [2/200] 的训练集准确率: 19.90 %
# Epoch [2/200] 的训练集loss: 2.28
# Epoch [2/200] 的验证集准确率: 20.52 %
# Epoch [2/200] 的验证集loss: 2.28
# 发现更好的模型，已保存到 best_model.pth
# ------------------------------
# ------------------------------
# Epoch [3/200] 的训练集准确率: 20.07 %
# Epoch [3/200] 的训练集loss: 2.26
# Epoch [3/200] 的验证集准确率: 20.82 %
# Epoch [3/200] 的验证集loss: 2.26
# 发现更好的模型，已保存到 best_model.pth
# ------------------------------
# ------------------------------
# Epoch [4/200] 的训练集准确率: 19.31 %
# Epoch [4/200] 的训练集loss: 2.23
# Epoch [4/200] 的验证集准确率: 19.76 %
# Epoch [4/200] 的验证集loss: 2.22
# ------------------------------
# ------------------------------
# Epoch [5/200] 的训练集准确率: 19.71 %
# Epoch [5/200] 的训练集loss: 2.18
# Epoch [5/200] 的验证集准确率: 20.30 %
# Epoch [5/200] 的验证集loss: 2.18
# ------------------------------
# ------------------------------
# Epoch [6/200] 的训练集准确率: 21.73 %
# Epoch [6/200] 的训练集loss: 2.13
# Epoch [6/200] 的验证集准确率: 21.72 %
# Epoch [6/200] 的验证集loss: 2.13
# 发现更好的模型，已保存到 best_model.pth
# ------------------------------
# ------------------------------
# Epoch [7/200] 的训练集准确率: 22.88 %
# Epoch [7/200] 的训练集loss: 2.09
# Epoch [7/200] 的验证集准确率: 23.00 %
# Epoch [7/200] 的验证集loss: 2.09
# 发现更好的模型，已保存到 best_model.pth
# ------------------------------
# ------------------------------
# Epoch [8/200] 的训练集准确率: 24.74 %
# Epoch [8/200] 的训练集loss: 2.06
# Epoch [8/200] 的验证集准确率: 25.30 %
# Epoch [8/200] 的验证集loss: 2.06
# 发现更好的模型，已保存到 best_model.pth
# ------------------------------
# ------------------------------
# Epoch [9/200] 的训练集准确率: 26.25 %
# Epoch [9/200] 的训练集loss: 2.04
# Epoch [9/200] 的验证集准确率: 26.38 %
# Epoch [9/200] 的验证集loss: 2.03
# 发现更好的模型，已保存到 best_model.pth
# ------------------------------
# ------------------------------
# Epoch [10/200] 的训练集准确率: 26.76 %
# Epoch [10/200] 的训练集loss: 2.01
# Epoch [10/200] 的验证集准确率: 27.32 %
# Epoch [10/200] 的验证集loss: 2.01
# 发现更好的模型，已保存到 best_model.pth
# ------------------------------
# ------------------------------
# Epoch [11/200] 的训练集准确率: 27.98 %
# Epoch [11/200] 的训练集loss: 1.99
# Epoch [11/200] 的验证集准确率: 28.38 %
# Epoch [11/200] 的验证集loss: 1.99
# 发现更好的模型，已保存到 best_model.pth
# ------------------------------
# ------------------------------
# Epoch [12/200] 的训练集准确率: 28.76 %
# Epoch [12/200] 的训练集loss: 1.98
# Epoch [12/200] 的验证集准确率: 29.24 %
# Epoch [12/200] 的验证集loss: 1.97
# 发现更好的模型，已保存到 best_model.pth
# ------------------------------
# ------------------------------
# Epoch [13/200] 的训练集准确率: 29.52 %
# Epoch [13/200] 的训练集loss: 1.96
# Epoch [13/200] 的验证集准确率: 29.56 %
# Epoch [13/200] 的验证集loss: 1.96
# 发现更好的模型，已保存到 best_model.pth
# ------------------------------
# ------------------------------
# Epoch [14/200] 的训练集准确率: 29.99 %
# Epoch [14/200] 的训练集loss: 1.95
# Epoch [14/200] 的验证集准确率: 30.32 %
# Epoch [14/200] 的验证集loss: 1.94
# 发现更好的模型，已保存到 best_model.pth
# ------------------------------
# ------------------------------
# Epoch [15/200] 的训练集准确率: 30.60 %
# Epoch [15/200] 的训练集loss: 1.94
# Epoch [15/200] 的验证集准确率: 30.98 %
# Epoch [15/200] 的验证集loss: 1.93
# 发现更好的模型，已保存到 best_model.pth
# ------------------------------
# ------------------------------
# Epoch [16/200] 的训练集准确率: 31.20 %
# Epoch [16/200] 的训练集loss: 1.92
# Epoch [16/200] 的验证集准确率: 31.78 %
# Epoch [16/200] 的验证集loss: 1.92
# 发现更好的模型，已保存到 best_model.pth
# ------------------------------
# ------------------------------
# Epoch [17/200] 的训练集准确率: 31.69 %
# Epoch [17/200] 的训练集loss: 1.91
# Epoch [17/200] 的验证集准确率: 32.34 %
# Epoch [17/200] 的验证集loss: 1.91
# 发现更好的模型，已保存到 best_model.pth
# ------------------------------
# ------------------------------
# Epoch [18/200] 的训练集准确率: 32.05 %
# Epoch [18/200] 的训练集loss: 1.90
# Epoch [18/200] 的验证集准确率: 32.62 %
# Epoch [18/200] 的验证集loss: 1.90
# 发现更好的模型，已保存到 best_model.pth
# ------------------------------
# ------------------------------
# Epoch [19/200] 的训练集准确率: 32.48 %
# Epoch [19/200] 的训练集loss: 1.89
# Epoch [19/200] 的验证集准确率: 32.98 %
# Epoch [19/200] 的验证集loss: 1.89
# 发现更好的模型，已保存到 best_model.pth
# ------------------------------
# ------------------------------
# Epoch [20/200] 的训练集准确率: 32.82 %
# Epoch [20/200] 的训练集loss: 1.88
# Epoch [20/200] 的验证集准确率: 33.26 %
# Epoch [20/200] 的验证集loss: 1.88
# 发现更好的模型，已保存到 best_model.pth
# ------------------------------
# ------------------------------
# Epoch [21/200] 的训练集准确率: 33.38 %
# Epoch [21/200] 的训练集loss: 1.87
# Epoch [21/200] 的验证集准确率: 34.32 %
# Epoch [21/200] 的验证集loss: 1.87
# 发现更好的模型，已保存到 best_model.pth
# ------------------------------
# ------------------------------
# Epoch [22/200] 的训练集准确率: 33.54 %
# Epoch [22/200] 的训练集loss: 1.86
# Epoch [22/200] 的验证集准确率: 34.32 %
# Epoch [22/200] 的验证集loss: 1.86
# ------------------------------
# ------------------------------
# Epoch [23/200] 的训练集准确率: 33.92 %
# Epoch [23/200] 的训练集loss: 1.85
# Epoch [23/200] 的验证集准确率: 35.06 %
# Epoch [23/200] 的验证集loss: 1.85
# 发现更好的模型，已保存到 best_model.pth
# ------------------------------
# ------------------------------
# Epoch [24/200] 的训练集准确率: 34.17 %
# Epoch [24/200] 的训练集loss: 1.84
# Epoch [24/200] 的验证集准确率: 35.06 %
# Epoch [24/200] 的验证集loss: 1.84
# ------------------------------
# ------------------------------
# Epoch [25/200] 的训练集准确率: 34.58 %
# Epoch [25/200] 的训练集loss: 1.84
# Epoch [25/200] 的验证集准确率: 35.70 %
# Epoch [25/200] 的验证集loss: 1.83
# 发现更好的模型，已保存到 best_model.pth
# ------------------------------
# ------------------------------
# Epoch [26/200] 的训练集准确率: 34.71 %
# Epoch [26/200] 的训练集loss: 1.83
# Epoch [26/200] 的验证集准确率: 35.56 %
# Epoch [26/200] 的验证集loss: 1.82
# ------------------------------
# ------------------------------
# Epoch [27/200] 的训练集准确率: 35.07 %
# Epoch [27/200] 的训练集loss: 1.82
# Epoch [27/200] 的验证集准确率: 35.98 %
# Epoch [27/200] 的验证集loss: 1.81
# 发现更好的模型，已保存到 best_model.pth
# ------------------------------
# ------------------------------
# Epoch [28/200] 的训练集准确率: 35.41 %
# Epoch [28/200] 的训练集loss: 1.81
# Epoch [28/200] 的验证集准确率: 36.18 %
# Epoch [28/200] 的验证集loss: 1.80
# 发现更好的模型，已保存到 best_model.pth
# ------------------------------
# ------------------------------
# Epoch [29/200] 的训练集准确率: 35.69 %
# Epoch [29/200] 的训练集loss: 1.80
# Epoch [29/200] 的验证集准确率: 36.76 %
# Epoch [29/200] 的验证集loss: 1.80
# 发现更好的模型，已保存到 best_model.pth
# ------------------------------
# ------------------------------
# Epoch [30/200] 的训练集准确率: 35.90 %
# Epoch [30/200] 的训练集loss: 1.80
# Epoch [30/200] 的验证集准确率: 36.52 %
# Epoch [30/200] 的验证集loss: 1.79
# ------------------------------
# ------------------------------
# Epoch [31/200] 的训练集准确率: 36.22 %
# Epoch [31/200] 的训练集loss: 1.79
# Epoch [31/200] 的验证集准确率: 36.88 %
# Epoch [31/200] 的验证集loss: 1.78
# 发现更好的模型，已保存到 best_model.pth
# ------------------------------
# ------------------------------
# Epoch [32/200] 的训练集准确率: 36.31 %
# Epoch [32/200] 的训练集loss: 1.78
# Epoch [32/200] 的验证集准确率: 36.90 %
# Epoch [32/200] 的验证集loss: 1.78
# 发现更好的模型，已保存到 best_model.pth
# ------------------------------
# ------------------------------
# Epoch [33/200] 的训练集准确率: 36.73 %
# Epoch [33/200] 的训练集loss: 1.77
# Epoch [33/200] 的验证集准确率: 37.82 %
# Epoch [33/200] 的验证集loss: 1.77
# 发现更好的模型，已保存到 best_model.pth
# ------------------------------
# ------------------------------
# Epoch [34/200] 的训练集准确率: 36.91 %
# Epoch [34/200] 的训练集loss: 1.77
# Epoch [34/200] 的验证集准确率: 37.58 %
# Epoch [34/200] 的验证集loss: 1.76
# ------------------------------
# ------------------------------
# Epoch [35/200] 的训练集准确率: 37.31 %
# Epoch [35/200] 的训练集loss: 1.76
# Epoch [35/200] 的验证集准确率: 37.58 %
# Epoch [35/200] 的验证集loss: 1.76
# ------------------------------
# ------------------------------
# Epoch [36/200] 的训练集准确率: 37.64 %
# Epoch [36/200] 的训练集loss: 1.75
# Epoch [36/200] 的验证集准确率: 37.86 %
# Epoch [36/200] 的验证集loss: 1.75
# 发现更好的模型，已保存到 best_model.pth
# ------------------------------
# ------------------------------
# Epoch [37/200] 的训练集准确率: 37.84 %
# Epoch [37/200] 的训练集loss: 1.75
# Epoch [37/200] 的验证集准确率: 38.00 %
# Epoch [37/200] 的验证集loss: 1.74
# 发现更好的模型，已保存到 best_model.pth
# ------------------------------
# ------------------------------
# Epoch [38/200] 的训练集准确率: 38.02 %
# Epoch [38/200] 的训练集loss: 1.74
# Epoch [38/200] 的验证集准确率: 37.86 %
# Epoch [38/200] 的验证集loss: 1.74
# ------------------------------
# ------------------------------
# Epoch [39/200] 的训练集准确率: 38.28 %
# Epoch [39/200] 的训练集loss: 1.73
# Epoch [39/200] 的验证集准确率: 38.04 %
# Epoch [39/200] 的验证集loss: 1.73
# 发现更好的模型，已保存到 best_model.pth
# ------------------------------
# ------------------------------
# Epoch [40/200] 的训练集准确率: 38.51 %
# Epoch [40/200] 的训练集loss: 1.73
# Epoch [40/200] 的验证集准确率: 38.36 %
# Epoch [40/200] 的验证集loss: 1.72
# 发现更好的模型，已保存到 best_model.pth
# ------------------------------
# ------------------------------
# Epoch [41/200] 的训练集准确率: 38.89 %
# Epoch [41/200] 的训练集loss: 1.72
# Epoch [41/200] 的验证集准确率: 38.90 %
# Epoch [41/200] 的验证集loss: 1.72
# 发现更好的模型，已保存到 best_model.pth
# ------------------------------
# ------------------------------
# Epoch [42/200] 的训练集准确率: 38.98 %
# Epoch [42/200] 的训练集loss: 1.71
# Epoch [42/200] 的验证集准确率: 38.92 %
# Epoch [42/200] 的验证集loss: 1.71
# 发现更好的模型，已保存到 best_model.pth
# ------------------------------
# ------------------------------
# Epoch [43/200] 的训练集准确率: 39.35 %
# Epoch [43/200] 的训练集loss: 1.71
# Epoch [43/200] 的验证集准确率: 38.80 %
# Epoch [43/200] 的验证集loss: 1.71
# ------------------------------
# ------------------------------
# Epoch [44/200] 的训练集准确率: 39.58 %
# Epoch [44/200] 的训练集loss: 1.70
# Epoch [44/200] 的验证集准确率: 38.78 %
# Epoch [44/200] 的验证集loss: 1.70
# ------------------------------
# ------------------------------
# Epoch [45/200] 的训练集准确率: 39.70 %
# Epoch [45/200] 的训练集loss: 1.69
# Epoch [45/200] 的验证集准确率: 39.46 %
# Epoch [45/200] 的验证集loss: 1.70
# 发现更好的模型，已保存到 best_model.pth
# ------------------------------
# ------------------------------
# Epoch [46/200] 的训练集准确率: 39.92 %
# Epoch [46/200] 的训练集loss: 1.69
# Epoch [46/200] 的验证集准确率: 39.72 %
# Epoch [46/200] 的验证集loss: 1.69
# 发现更好的模型，已保存到 best_model.pth
# ------------------------------
# ------------------------------
# Epoch [47/200] 的训练集准确率: 40.17 %
# Epoch [47/200] 的训练集loss: 1.68
# Epoch [47/200] 的验证集准确率: 39.50 %
# Epoch [47/200] 的验证集loss: 1.68
# ------------------------------
# ------------------------------
# Epoch [48/200] 的训练集准确率: 40.31 %
# Epoch [48/200] 的训练集loss: 1.68
# Epoch [48/200] 的验证集准确率: 39.88 %
# Epoch [48/200] 的验证集loss: 1.68
# 发现更好的模型，已保存到 best_model.pth
# ------------------------------
# ------------------------------
# Epoch [49/200] 的训练集准确率: 40.63 %
# Epoch [49/200] 的训练集loss: 1.67
# Epoch [49/200] 的验证集准确率: 39.82 %
# Epoch [49/200] 的验证集loss: 1.68
# ------------------------------
# ------------------------------
# Epoch [50/200] 的训练集准确率: 40.86 %
# Epoch [50/200] 的训练集loss: 1.67
# Epoch [50/200] 的验证集准确率: 39.62 %
# Epoch [50/200] 的验证集loss: 1.67
# ------------------------------
# ------------------------------
# Epoch [51/200] 的训练集准确率: 40.96 %
# Epoch [51/200] 的训练集loss: 1.66
# Epoch [51/200] 的验证集准确率: 40.50 %
# Epoch [51/200] 的验证集loss: 1.67
# 发现更好的模型，已保存到 best_model.pth
# ------------------------------
# ------------------------------
# Epoch [52/200] 的训练集准确率: 41.19 %
# Epoch [52/200] 的训练集loss: 1.66
# Epoch [52/200] 的验证集准确率: 40.34 %
# Epoch [52/200] 的验证集loss: 1.66
# ------------------------------
# ------------------------------
# Epoch [53/200] 的训练集准确率: 41.42 %
# Epoch [53/200] 的训练集loss: 1.65
# Epoch [53/200] 的验证集准确率: 40.64 %
# Epoch [53/200] 的验证集loss: 1.66
# 发现更好的模型，已保存到 best_model.pth
# ------------------------------
# ------------------------------
# Epoch [54/200] 的训练集准确率: 41.54 %
# Epoch [54/200] 的训练集loss: 1.65
# Epoch [54/200] 的验证集准确率: 40.86 %
# Epoch [54/200] 的验证集loss: 1.65
# 发现更好的模型，已保存到 best_model.pth
# ------------------------------
# ------------------------------
# Epoch [55/200] 的训练集准确率: 41.70 %
# Epoch [55/200] 的训练集loss: 1.64
# Epoch [55/200] 的验证集准确率: 40.90 %
# Epoch [55/200] 的验证集loss: 1.65
# 发现更好的模型，已保存到 best_model.pth
# ------------------------------
# ------------------------------
# Epoch [56/200] 的训练集准确率: 41.90 %
# Epoch [56/200] 的训练集loss: 1.64
# Epoch [56/200] 的验证集准确率: 41.30 %
# Epoch [56/200] 的验证集loss: 1.65
# 发现更好的模型，已保存到 best_model.pth
# ------------------------------
# ------------------------------
# Epoch [57/200] 的训练集准确率: 42.12 %
# Epoch [57/200] 的训练集loss: 1.64
# Epoch [57/200] 的验证集准确率: 41.30 %
# Epoch [57/200] 的验证集loss: 1.64
# ------------------------------
# ------------------------------
# Epoch [58/200] 的训练集准确率: 42.34 %
# Epoch [58/200] 的训练集loss: 1.63
# Epoch [58/200] 的验证集准确率: 41.28 %
# Epoch [58/200] 的验证集loss: 1.64
# ------------------------------
# ------------------------------
# Epoch [59/200] 的训练集准确率: 42.50 %
# Epoch [59/200] 的训练集loss: 1.63
# Epoch [59/200] 的验证集准确率: 41.32 %
# Epoch [59/200] 的验证集loss: 1.64
# 发现更好的模型，已保存到 best_model.pth
# ------------------------------
# ------------------------------
# Epoch [60/200] 的训练集准确率: 42.60 %
# Epoch [60/200] 的训练集loss: 1.62
# Epoch [60/200] 的验证集准确率: 41.76 %
# Epoch [60/200] 的验证集loss: 1.63
# 发现更好的模型，已保存到 best_model.pth
# ------------------------------
# ------------------------------
# Epoch [61/200] 的训练集准确率: 42.91 %
# Epoch [61/200] 的训练集loss: 1.62
# Epoch [61/200] 的验证集准确率: 41.92 %
# Epoch [61/200] 的验证集loss: 1.63
# 发现更好的模型，已保存到 best_model.pth
# ------------------------------
# ------------------------------
# Epoch [62/200] 的训练集准确率: 43.09 %
# Epoch [62/200] 的训练集loss: 1.61
# Epoch [62/200] 的验证集准确率: 42.32 %
# Epoch [62/200] 的验证集loss: 1.62
# 发现更好的模型，已保存到 best_model.pth
# ------------------------------
# ------------------------------
# Epoch [63/200] 的训练集准确率: 43.10 %
# Epoch [63/200] 的训练集loss: 1.61
# Epoch [63/200] 的验证集准确率: 42.08 %
# Epoch [63/200] 的验证集loss: 1.62
# ------------------------------
# ------------------------------
# Epoch [64/200] 的训练集准确率: 43.43 %
# Epoch [64/200] 的训练集loss: 1.61
# Epoch [64/200] 的验证集准确率: 42.26 %
# Epoch [64/200] 的验证集loss: 1.61
# ------------------------------
# ------------------------------
# Epoch [65/200] 的训练集准确率: 43.48 %
# Epoch [65/200] 的训练集loss: 1.60
# Epoch [65/200] 的验证集准确率: 42.44 %
# Epoch [65/200] 的验证集loss: 1.61
# 发现更好的模型，已保存到 best_model.pth
# ------------------------------
# ------------------------------
# Epoch [66/200] 的训练集准确率: 43.42 %
# Epoch [66/200] 的训练集loss: 1.60
# Epoch [66/200] 的验证集准确率: 42.54 %
# Epoch [66/200] 的验证集loss: 1.61
# 发现更好的模型，已保存到 best_model.pth
# ------------------------------
# ------------------------------
# Epoch [67/200] 的训练集准确率: 43.69 %
# Epoch [67/200] 的训练集loss: 1.59
# Epoch [67/200] 的验证集准确率: 42.72 %
# Epoch [67/200] 的验证集loss: 1.61
# 发现更好的模型，已保存到 best_model.pth
# ------------------------------
# ------------------------------
# Epoch [68/200] 的训练集准确率: 43.88 %
# Epoch [68/200] 的训练集loss: 1.59
# Epoch [68/200] 的验证集准确率: 42.86 %
# Epoch [68/200] 的验证集loss: 1.60
# 发现更好的模型，已保存到 best_model.pth
# ------------------------------
# ------------------------------
# Epoch [69/200] 的训练集准确率: 44.10 %
# Epoch [69/200] 的训练集loss: 1.58
# Epoch [69/200] 的验证集准确率: 42.92 %
# Epoch [69/200] 的验证集loss: 1.60
# 发现更好的模型，已保存到 best_model.pth
# ------------------------------
# ------------------------------
# Epoch [70/200] 的训练集准确率: 44.20 %
# Epoch [70/200] 的训练集loss: 1.58
# Epoch [70/200] 的验证集准确率: 43.14 %
# Epoch [70/200] 的验证集loss: 1.60
# 发现更好的模型，已保存到 best_model.pth
# ------------------------------
# ------------------------------
# Epoch [71/200] 的训练集准确率: 44.27 %
# Epoch [71/200] 的训练集loss: 1.58
# Epoch [71/200] 的验证集准确率: 43.08 %
# Epoch [71/200] 的验证集loss: 1.59
# ------------------------------
