# %% [markdown]
# ## 准备数据

# %%
import torch
import torch.nn as nn
import torch.utils.data as data
import torch.optim as optim
import torch.nn.functional as F
import numpy as np
import pickle
from sklearn.model_selection import train_test_split

def unpickle(file):
    with open(file, 'rb') as fo:
        dict = pickle.load(fo, encoding='latin1')
    return dict

cifar10_dir = '/home/lc/d2l-zh/exercise/cifar-10-python/cifar-10-batches-py/'
all_train_data = []
all_train_labels = []

for i in range(1, 6):
    file_path = f'{cifar10_dir}/data_batch_{i}'
    data_dict = unpickle(file_path)
    all_train_data.append(data_dict['data'])
    all_train_labels.extend(data_dict['labels'])

train_data_np = np.concatenate(all_train_data)
train_labels_np = np.array(all_train_labels)

X_train, X_val, y_train, y_val = train_test_split(
    train_data_np, 
    train_labels_np, 
    test_size=0.1, 
    random_state=42,
    stratify=train_labels_np 
)

test_file_path = f'{cifar10_dir}/test_batch'
test_dict = unpickle(test_file_path)
X_test = test_dict['data']
y_test = np.array(test_dict['labels'])

print(f"测试数据 (X_test) 形状: {X_test.shape}")
print(f"测试标签 (y_test) 形状: {y_test.shape}")

print(f"原始训练数据形状: {train_data_np.shape}")
print("-" * 30)
print(f"划分后的训练数据 (X_train) 形状: {X_train.shape}")
print(f"划分后的训练标签 (y_train) 形状: {y_train.shape}")
print(f"划分后的验证数据 (X_val) 形状: {X_val.shape}")
print(f"划分后的验证标签 (y_val) 形状: {y_val.shape}")
# Out:
# 测试数据 (X_test) 形状: (10000, 3072)
# 测试标签 (y_test) 形状: (10000,)
# 原始训练数据形状: (50000, 3072)
# ------------------------------
# 划分后的训练数据 (X_train) 形状: (45000, 3072)
# 划分后的训练标签 (y_train) 形状: (45000,)
# 划分后的验证数据 (X_val) 形状: (5000, 3072)
# 划分后的验证标签 (y_val) 形状: (5000,)

# %%
class SimpleCIFAR10Dataset(data.Dataset):
    """
    一个极简的自定义数据集类。
    它直接接收NumPy数据，并在需要时返回PyTorch张量。
    """
    def __init__(self, images, labels):
        """
        初始化函数。
        Args:
            images (numpy.ndarray): 图像数据，形状为 (样本数, 3072)，代表一维形式。
            labels (numpy.ndarray): 标签数据，形状为 (样本数,)。
        """
        # 将数据转换为 PyTorch Tensor。这是与 PyTorch 模型交互的必要步骤。
        # 图像数据需要是浮点型以供模型计算。
        self.images = torch.from_numpy(images / 255.0).float()
        # 标签在计算损失函数时通常需要是长整型 (LongTensor)。
        self.labels = torch.from_numpy(labels).long()

    def __len__(self):
        """返回数据集的样本总数。"""
        return len(self.labels)

    def __getitem__(self, idx):
        """根据索引获取一个样本（图像和标签）。"""
        return self.images[idx], self.labels[idx]

# 1. 实例化训练和验证数据集
train_dataset = SimpleCIFAR10Dataset(X_train, y_train)
val_dataset = SimpleCIFAR10Dataset(X_val, y_val)
test_dataset = SimpleCIFAR10Dataset(X_test, y_test)

# 2. 创建 DataLoader
batch_size = 2000  # 定义每个批次的大小

train_loader = data.DataLoader(
    dataset=train_dataset,
    batch_size=batch_size,
    shuffle=True,  # 训练时打乱数据顺序以增强模型泛化能力
    num_workers=16, # 增加工作进程数
    pin_memory=True
)

val_loader = data.DataLoader(
    dataset=val_dataset,
    batch_size=batch_size,
    shuffle=False, # 验证时通常不需要打乱
    num_workers=16, # 增加工作进程数
    pin_memory=True
)

test_loader = data.DataLoader(
    dataset=test_dataset,
    batch_size=batch_size, # 可以和训练时用一样的batch_size
    shuffle=False,      # 测试时不需要打乱数据
    num_workers=16, # 增加工作进程数
    pin_memory=True
)

# 3. 验证 DataLoader 是否工作正常
print("成功创建最简化的 DataLoader！")
print("-" * 30)

# 从 train_loader 中获取一个批次的数据进行检查
data_batch, labels_batch = next(iter(train_loader))
print(f"一个训练批次的数据 (images) 形状: {data_batch.shape}")
print(f"一个训练批次的标签 (labels) 形状: {labels_batch.shape}")
print(f"批次数据的类型: {data_batch.dtype}")
print(f"批次标签的类型: {labels_batch.dtype}")
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
# Out:
# 成功创建最简化的 DataLoader！
# ------------------------------
# 一个训练批次的数据 (images) 形状: torch.Size([2000, 3072])
# 一个训练批次的标签 (labels) 形状: torch.Size([2000])
# 批次数据的类型: torch.float32
# 批次标签的类型: torch.int64
# Using device: cuda

# %% [markdown]
# ## 建立模型

# %%
class myModel(nn.Module):
    def __init__(self):
        super(myModel,self).__init__()
        self.linear1 = nn.Linear(3072,1024)
        self.linear2 = nn.Linear(1024,512)
        self.linear3 = nn.Linear(512,10)
        self.dropout = nn.Dropout(p=0.1)
    def forward(self, inp):
        x = self.linear1(inp)
        x = torch.relu(x)
        x = self.dropout(x)
        x = self.linear2(x)
        x = torch.relu(x)
        x = self.dropout(x)
        logits = self.linear3(x)
        return logits
        
model = myModel()

optimizer = optim.Adam(model.parameters(),lr = 0.001, weight_decay=1e-4)
# optimizer = optim.Adam(model.parameters(),lr = 0.001)

def eval_model(model, test_loader, criterion):
    """
    在测试集上评估模型的最终性能。
    """
    model.eval()  # 切换到评估模式
    test_loss = 0.0
    correct = 0
    total = 0
    with torch.no_grad(): # 在此模式下，所有计算都不会被记录用于反向传播
        for images, labels in test_loader:
            images = images.to(device)
            labels = labels.to(device)
            outputs = model(images)
            loss = criterion(outputs, labels)
            test_loss += loss.item()

            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

    # 计算平均损失和准确率
    avg_loss = test_loss / len(test_loader)
    accuracy = 100 * correct / total

    return accuracy, avg_loss

# %% [markdown]
# ## 计算 loss

# %%
criterion = nn.CrossEntropyLoss()

# %% [markdown]
# ## 实际训练

# %%
num_epochs = 70
def train_one_step(model,optimizer,train_loader):
    model.train()
    for x_batch,y_batch in train_loader:
        x_batch = x_batch.to(device)
        y_batch = y_batch.to(device)
        optimizer.zero_grad()
        logits = model(x_batch)
        loss =  criterion(logits,y_batch)
        loss.backward()
        optimizer.step()

if __name__ == '__main__':
    model.to(device)
    best_val_accuracy = 0.0
    best_model_path = "best_model.pth"
    for i in range(num_epochs):
        train_one_step(model,optimizer,train_loader)
        train_accuracy, train_loss = eval_model(model, train_loader, criterion)
        val_accuracy, val_loss = eval_model(model, val_loader, criterion)
        print("-" * 30)
        print(f'Epoch [{i+1}/{num_epochs}] 的训练集准确率: {train_accuracy:.2f} %')
        print(f'Epoch [{i+1}/{num_epochs}] 的训练集loss: {train_loss:.2f}')
        print(f'Epoch [{i+1}/{num_epochs}] 的验证集准确率: {val_accuracy:.2f} %')
        print(f'Epoch [{i+1}/{num_epochs}] 的验证集loss: {val_loss:.2f}')
        if val_accuracy > best_val_accuracy:
            best_val_accuracy = val_accuracy
            torch.save(model.state_dict(), best_model_path)
            print(f"发现更好的模型，已保存到 {best_model_path}")
        print("-" * 30)
    print(f"加载最佳模型 ({best_model_path}) 进行最终测试...")
    model.load_state_dict(torch.load(best_model_path))

    # 使用加载了最佳权重的模型进行测试
    test_accuracy, test_loss = eval_model(model, test_loader, criterion)
    print(f'测试集准确率: {test_accuracy:.2f} %')
    print(f'测试集loss: {test_loss:.2f} %')
# Out:
# ------------------------------
# Epoch [1/200] 的训练集准确率: 29.93 %
# Epoch [1/200] 的训练集loss: 1.96 %
# Epoch [1/200] 的验证集准确率: 29.98 %
# Epoch [1/200] 的验证集loss: 1.96 %
# 发现更好的模型，已保存到 best_model.pth
# ------------------------------
# ------------------------------
# Epoch [2/200] 的训练集准确率: 34.75 %
# Epoch [2/200] 的训练集loss: 1.84 %
# Epoch [2/200] 的验证集准确率: 34.70 %
# Epoch [2/200] 的验证集loss: 1.84 %
# 发现更好的模型，已保存到 best_model.pth
# ------------------------------
# ------------------------------
# Epoch [3/200] 的训练集准确率: 37.80 %
# Epoch [3/200] 的训练集loss: 1.75 %
# Epoch [3/200] 的验证集准确率: 37.66 %
# Epoch [3/200] 的验证集loss: 1.74 %
# 发现更好的模型，已保存到 best_model.pth
# ------------------------------
# ------------------------------
# Epoch [4/200] 的训练集准确率: 40.05 %
# Epoch [4/200] 的训练集loss: 1.69 %
# Epoch [4/200] 的验证集准确率: 39.90 %
# Epoch [4/200] 的验证集loss: 1.70 %
# 发现更好的模型，已保存到 best_model.pth
# ------------------------------
# ------------------------------
# Epoch [5/200] 的训练集准确率: 41.79 %
# Epoch [5/200] 的训练集loss: 1.64 %
# Epoch [5/200] 的验证集准确率: 41.26 %
# Epoch [5/200] 的验证集loss: 1.65 %
# 发现更好的模型，已保存到 best_model.pth
# ------------------------------
# ------------------------------
# Epoch [6/200] 的训练集准确率: 43.59 %
# Epoch [6/200] 的训练集loss: 1.59 %
# Epoch [6/200] 的验证集准确率: 43.06 %
# Epoch [6/200] 的验证集loss: 1.60 %
# 发现更好的模型，已保存到 best_model.pth
# ------------------------------
# ------------------------------
# Epoch [7/200] 的训练集准确率: 43.02 %
# Epoch [7/200] 的训练集loss: 1.61 %
# Epoch [7/200] 的验证集准确率: 42.76 %
# Epoch [7/200] 的验证集loss: 1.63 %
# ------------------------------
# ------------------------------
# Epoch [8/200] 的训练集准确率: 46.07 %
# Epoch [8/200] 的训练集loss: 1.52 %
# Epoch [8/200] 的验证集准确率: 45.30 %
# Epoch [8/200] 的验证集loss: 1.54 %
# 发现更好的模型，已保存到 best_model.pth
# ------------------------------
# ------------------------------
# Epoch [9/200] 的训练集准确率: 46.59 %
# Epoch [9/200] 的训练集loss: 1.51 %
# Epoch [9/200] 的验证集准确率: 45.28 %
# Epoch [9/200] 的验证集loss: 1.53 %
# ------------------------------
# ------------------------------
# Epoch [10/200] 的训练集准确率: 47.72 %
# Epoch [10/200] 的训练集loss: 1.47 %
# Epoch [10/200] 的验证集准确率: 46.12 %
# Epoch [10/200] 的验证集loss: 1.51 %
# 发现更好的模型，已保存到 best_model.pth
# ------------------------------
# ------------------------------
# Epoch [11/200] 的训练集准确率: 48.06 %
# Epoch [11/200] 的训练集loss: 1.47 %
# Epoch [11/200] 的验证集准确率: 46.52 %
# Epoch [11/200] 的验证集loss: 1.51 %
# 发现更好的模型，已保存到 best_model.pth
# ------------------------------
# ------------------------------
# Epoch [12/200] 的训练集准确率: 49.13 %
# Epoch [12/200] 的训练集loss: 1.44 %
# Epoch [12/200] 的验证集准确率: 47.28 %
# Epoch [12/200] 的验证集loss: 1.49 %
# 发现更好的模型，已保存到 best_model.pth
# ------------------------------
# ------------------------------
# Epoch [13/200] 的训练集准确率: 50.08 %
# Epoch [13/200] 的训练集loss: 1.42 %
# Epoch [13/200] 的验证集准确率: 46.92 %
# Epoch [13/200] 的验证集loss: 1.47 %
# ------------------------------
# ------------------------------
# Epoch [14/200] 的训练集准确率: 50.76 %
# Epoch [14/200] 的训练集loss: 1.39 %
# Epoch [14/200] 的验证集准确率: 47.96 %
# Epoch [14/200] 的验证集loss: 1.46 %
# 发现更好的模型，已保存到 best_model.pth
# ------------------------------
# ------------------------------
# Epoch [15/200] 的训练集准确率: 49.72 %
# Epoch [15/200] 的训练集loss: 1.41 %
# Epoch [15/200] 的验证集准确率: 47.32 %
# Epoch [15/200] 的验证集loss: 1.48 %
# ------------------------------
# ------------------------------
# Epoch [16/200] 的训练集准确率: 51.73 %
# Epoch [16/200] 的训练集loss: 1.37 %
# Epoch [16/200] 的验证集准确率: 49.16 %
# Epoch [16/200] 的验证集loss: 1.44 %
# 发现更好的模型，已保存到 best_model.pth
# ------------------------------
# ------------------------------
# Epoch [17/200] 的训练集准确率: 52.60 %
# Epoch [17/200] 的训练集loss: 1.35 %
# Epoch [17/200] 的验证集准确率: 49.52 %
# Epoch [17/200] 的验证集loss: 1.42 %
# 发现更好的模型，已保存到 best_model.pth
# ------------------------------
# ------------------------------
# Epoch [18/200] 的训练集准确率: 52.54 %
# Epoch [18/200] 的训练集loss: 1.34 %
# Epoch [18/200] 的验证集准确率: 49.30 %
# Epoch [18/200] 的验证集loss: 1.42 %
# ------------------------------
# ------------------------------
# Epoch [19/200] 的训练集准确率: 52.78 %
# Epoch [19/200] 的训练集loss: 1.34 %
# Epoch [19/200] 的验证集准确率: 49.68 %
# Epoch [19/200] 的验证集loss: 1.43 %
# 发现更好的模型，已保存到 best_model.pth
# ------------------------------
# ------------------------------
# Epoch [20/200] 的训练集准确率: 52.82 %
# Epoch [20/200] 的训练集loss: 1.33 %
# Epoch [20/200] 的验证集准确率: 49.30 %
# Epoch [20/200] 的验证集loss: 1.43 %
# ------------------------------
# ------------------------------
# Epoch [21/200] 的训练集准确率: 53.10 %
# Epoch [21/200] 的训练集loss: 1.32 %
# Epoch [21/200] 的验证集准确率: 49.34 %
# Epoch [21/200] 的验证集loss: 1.42 %
# ------------------------------
# ------------------------------
# Epoch [22/200] 的训练集准确率: 54.89 %
# Epoch [22/200] 的训练集loss: 1.27 %
# Epoch [22/200] 的验证集准确率: 51.16 %
# Epoch [22/200] 的验证集loss: 1.38 %
# 发现更好的模型，已保存到 best_model.pth
# ------------------------------
# ------------------------------
# Epoch [23/200] 的训练集准确率: 55.56 %
# Epoch [23/200] 的训练集loss: 1.27 %
# Epoch [23/200] 的验证集准确率: 50.62 %
# Epoch [23/200] 的验证集loss: 1.39 %
# ------------------------------
# ------------------------------
# Epoch [24/200] 的训练集准确率: 55.43 %
# Epoch [24/200] 的训练集loss: 1.26 %
# Epoch [24/200] 的验证集准确率: 50.34 %
# Epoch [24/200] 的验证集loss: 1.39 %
# ------------------------------
# ------------------------------
# Epoch [25/200] 的训练集准确率: 55.85 %
# Epoch [25/200] 的训练集loss: 1.24 %
# Epoch [25/200] 的验证集准确率: 51.26 %
# Epoch [25/200] 的验证集loss: 1.38 %
# 发现更好的模型，已保存到 best_model.pth
# ------------------------------
# ------------------------------
# Epoch [26/200] 的训练集准确率: 54.83 %
# Epoch [26/200] 的训练集loss: 1.28 %
# Epoch [26/200] 的验证集准确率: 49.22 %
# Epoch [26/200] 的验证集loss: 1.42 %
# ------------------------------
# ------------------------------
# Epoch [27/200] 的训练集准确率: 56.59 %
# Epoch [27/200] 的训练集loss: 1.23 %
# Epoch [27/200] 的验证集准确率: 51.52 %
# Epoch [27/200] 的验证集loss: 1.38 %
# 发现更好的模型，已保存到 best_model.pth
# ------------------------------
# ------------------------------
# Epoch [28/200] 的训练集准确率: 56.41 %
# Epoch [28/200] 的训练集loss: 1.24 %
# Epoch [28/200] 的验证集准确率: 50.92 %
# Epoch [28/200] 的验证集loss: 1.39 %
# ------------------------------
# ------------------------------
# Epoch [29/200] 的训练集准确率: 58.47 %
# Epoch [29/200] 的训练集loss: 1.19 %
# Epoch [29/200] 的验证集准确率: 52.18 %
# Epoch [29/200] 的验证集loss: 1.35 %
# 发现更好的模型，已保存到 best_model.pth
# ------------------------------
# ------------------------------
# Epoch [30/200] 的训练集准确率: 59.30 %
# Epoch [30/200] 的训练集loss: 1.16 %
# Epoch [30/200] 的验证集准确率: 52.98 %
# Epoch [30/200] 的验证集loss: 1.32 %
# 发现更好的模型，已保存到 best_model.pth
# ------------------------------
# ------------------------------
# Epoch [31/200] 的训练集准确率: 59.32 %
# Epoch [31/200] 的训练集loss: 1.16 %
# Epoch [31/200] 的验证集准确率: 51.96 %
# Epoch [31/200] 的验证集loss: 1.33 %
# ------------------------------
# ------------------------------
# Epoch [32/200] 的训练集准确率: 59.48 %
# Epoch [32/200] 的训练集loss: 1.15 %
# Epoch [32/200] 的验证集准确率: 53.02 %
# Epoch [32/200] 的验证集loss: 1.33 %
# 发现更好的模型，已保存到 best_model.pth
# ------------------------------
# ------------------------------
# Epoch [33/200] 的训练集准确率: 60.55 %
# Epoch [33/200] 的训练集loss: 1.12 %
# Epoch [33/200] 的验证集准确率: 53.14 %
# Epoch [33/200] 的验证集loss: 1.31 %
# 发现更好的模型，已保存到 best_model.pth
# ------------------------------
# ------------------------------
# Epoch [34/200] 的训练集准确率: 60.66 %
# Epoch [34/200] 的训练集loss: 1.11 %
# Epoch [34/200] 的验证集准确率: 53.00 %
# Epoch [34/200] 的验证集loss: 1.32 %
# ------------------------------
# ------------------------------
# Epoch [35/200] 的训练集准确率: 61.62 %
# Epoch [35/200] 的训练集loss: 1.11 %
# Epoch [35/200] 的验证集准确率: 53.36 %
# Epoch [35/200] 的验证集loss: 1.31 %
# 发现更好的模型，已保存到 best_model.pth
# ------------------------------
# ------------------------------
# Epoch [36/200] 的训练集准确率: 61.75 %
# Epoch [36/200] 的训练集loss: 1.10 %
# Epoch [36/200] 的验证集准确率: 53.26 %
# Epoch [36/200] 的验证集loss: 1.31 %
# ------------------------------
# ------------------------------
# Epoch [37/200] 的训练集准确率: 62.18 %
# Epoch [37/200] 的训练集loss: 1.09 %
# Epoch [37/200] 的验证集准确率: 53.36 %
# Epoch [37/200] 的验证集loss: 1.31 %
# ------------------------------
# ------------------------------
# Epoch [38/200] 的训练集准确率: 60.90 %
# Epoch [38/200] 的训练集loss: 1.11 %
# Epoch [38/200] 的验证集准确率: 52.56 %
# Epoch [38/200] 的验证集loss: 1.35 %
# ------------------------------
# ------------------------------
# Epoch [39/200] 的训练集准确率: 61.97 %
# Epoch [39/200] 的训练集loss: 1.08 %
# Epoch [39/200] 的验证集准确率: 53.06 %
# Epoch [39/200] 的验证集loss: 1.32 %
# ------------------------------
# ------------------------------
# Epoch [40/200] 的训练集准确率: 63.63 %
# Epoch [40/200] 的训练集loss: 1.05 %
# Epoch [40/200] 的验证集准确率: 53.68 %
# Epoch [40/200] 的验证集loss: 1.30 %
# 发现更好的模型，已保存到 best_model.pth
# ------------------------------
# ------------------------------
# Epoch [41/200] 的训练集准确率: 63.76 %
# Epoch [41/200] 的训练集loss: 1.05 %
# Epoch [41/200] 的验证集准确率: 53.96 %
# Epoch [41/200] 的验证集loss: 1.31 %
# 发现更好的模型，已保存到 best_model.pth
# ------------------------------
# ------------------------------
# Epoch [42/200] 的训练集准确率: 63.35 %
# Epoch [42/200] 的训练集loss: 1.04 %
# Epoch [42/200] 的验证集准确率: 53.58 %
# Epoch [42/200] 的验证集loss: 1.32 %
# ------------------------------
# ------------------------------
# Epoch [43/200] 的训练集准确率: 63.17 %
# Epoch [43/200] 的训练集loss: 1.04 %
# Epoch [43/200] 的验证集准确率: 52.96 %
# Epoch [43/200] 的验证集loss: 1.33 %
# ------------------------------
# ------------------------------
# Epoch [44/200] 的训练集准确率: 63.53 %
# Epoch [44/200] 的训练集loss: 1.04 %
# Epoch [44/200] 的验证集准确率: 53.28 %
# Epoch [44/200] 的验证集loss: 1.32 %
# ------------------------------
# ------------------------------
# Epoch [45/200] 的训练集准确率: 65.84 %
# Epoch [45/200] 的训练集loss: 0.99 %
# Epoch [45/200] 的验证集准确率: 54.48 %
# Epoch [45/200] 的验证集loss: 1.29 %
# 发现更好的模型，已保存到 best_model.pth
# ------------------------------
# ------------------------------
# Epoch [46/200] 的训练集准确率: 64.65 %
# Epoch [46/200] 的训练集loss: 1.00 %
# Epoch [46/200] 的验证集准确率: 52.98 %
# Epoch [46/200] 的验证集loss: 1.31 %
# ------------------------------
# ------------------------------
# Epoch [47/200] 的训练集准确率: 66.08 %
# Epoch [47/200] 的训练集loss: 0.97 %
# Epoch [47/200] 的验证集准确率: 53.96 %
# Epoch [47/200] 的验证集loss: 1.30 %
# ------------------------------
# ------------------------------
# Epoch [48/200] 的训练集准确率: 66.22 %
# Epoch [48/200] 的训练集loss: 0.96 %
# Epoch [48/200] 的验证集准确率: 54.92 %
# Epoch [48/200] 的验证集loss: 1.28 %
# 发现更好的模型，已保存到 best_model.pth
# ------------------------------
# ------------------------------
# Epoch [49/200] 的训练集准确率: 66.39 %
# Epoch [49/200] 的训练集loss: 0.96 %
# Epoch [49/200] 的验证集准确率: 54.96 %
# Epoch [49/200] 的验证集loss: 1.29 %
# 发现更好的模型，已保存到 best_model.pth
# ------------------------------
# ------------------------------
# Epoch [50/200] 的训练集准确率: 67.46 %
# Epoch [50/200] 的训练集loss: 0.94 %
# Epoch [50/200] 的验证集准确率: 55.14 %
# Epoch [50/200] 的验证集loss: 1.28 %
# 发现更好的模型，已保存到 best_model.pth
# ------------------------------
# ------------------------------
# Epoch [51/200] 的训练集准确率: 67.36 %
# Epoch [51/200] 的训练集loss: 0.94 %
# Epoch [51/200] 的验证集准确率: 54.94 %
# Epoch [51/200] 的验证集loss: 1.29 %
# ------------------------------
# ------------------------------
# Epoch [52/200] 的训练集准确率: 68.34 %
# Epoch [52/200] 的训练集loss: 0.91 %
# Epoch [52/200] 的验证集准确率: 55.72 %
# Epoch [52/200] 的验证集loss: 1.27 %
# 发现更好的模型，已保存到 best_model.pth
# ------------------------------
# ------------------------------
# Epoch [53/200] 的训练集准确率: 69.10 %
# Epoch [53/200] 的训练集loss: 0.90 %
# Epoch [53/200] 的验证集准确率: 55.32 %
# Epoch [53/200] 的验证集loss: 1.27 %
# ------------------------------
# ------------------------------
# Epoch [54/200] 的训练集准确率: 68.98 %
# Epoch [54/200] 的训练集loss: 0.89 %
# Epoch [54/200] 的验证集准确率: 54.90 %
# Epoch [54/200] 的验证集loss: 1.28 %
# ------------------------------
# ------------------------------
# Epoch [55/200] 的训练集准确率: 70.11 %
# Epoch [55/200] 的训练集loss: 0.88 %
# Epoch [55/200] 的验证集准确率: 56.20 %
# Epoch [55/200] 的验证集loss: 1.27 %
# 发现更好的模型，已保存到 best_model.pth
# ------------------------------
# ------------------------------
# Epoch [56/200] 的训练集准确率: 69.35 %
# Epoch [56/200] 的训练集loss: 0.88 %
# Epoch [56/200] 的验证集准确率: 54.96 %
# Epoch [56/200] 的验证集loss: 1.29 %
# ------------------------------
# ------------------------------
# Epoch [57/200] 的训练集准确率: 70.36 %
# Epoch [57/200] 的训练集loss: 0.86 %
# Epoch [57/200] 的验证集准确率: 55.14 %
# Epoch [57/200] 的验证集loss: 1.28 %
# ------------------------------
# ------------------------------
# Epoch [58/200] 的训练集准确率: 71.65 %
# Epoch [58/200] 的训练集loss: 0.84 %
# Epoch [58/200] 的验证集准确率: 55.90 %
# Epoch [58/200] 的验证集loss: 1.25 %
# ------------------------------
# ------------------------------
# Epoch [59/200] 的训练集准确率: 71.90 %
# Epoch [59/200] 的训练集loss: 0.83 %
# Epoch [59/200] 的验证集准确率: 55.52 %
# Epoch [59/200] 的验证集loss: 1.27 %
# ------------------------------
# ------------------------------
# Epoch [60/200] 的训练集准确率: 70.95 %
# Epoch [60/200] 的训练集loss: 0.84 %
# Epoch [60/200] 的验证集准确率: 55.14 %
# Epoch [60/200] 的验证集loss: 1.28 %
# ------------------------------
# ------------------------------
# Epoch [61/200] 的训练集准确率: 72.24 %
# Epoch [61/200] 的训练集loss: 0.81 %
# Epoch [61/200] 的验证集准确率: 55.90 %
# Epoch [61/200] 的验证集loss: 1.28 %
# ------------------------------
# ------------------------------
# Epoch [62/200] 的训练集准确率: 71.91 %
# Epoch [62/200] 的训练集loss: 0.82 %
# Epoch [62/200] 的验证集准确率: 55.20 %
# Epoch [62/200] 的验证集loss: 1.29 %
# ------------------------------
# ------------------------------
# Epoch [63/200] 的训练集准确率: 71.63 %
# Epoch [63/200] 的训练集loss: 0.82 %
# Epoch [63/200] 的验证集准确率: 55.12 %
# Epoch [63/200] 的验证集loss: 1.30 %
# ------------------------------
# ------------------------------
# Epoch [64/200] 的训练集准确率: 72.63 %
# Epoch [64/200] 的训练集loss: 0.80 %
# Epoch [64/200] 的验证集准确率: 55.06 %
# Epoch [64/200] 的验证集loss: 1.30 %
# ------------------------------
# ------------------------------
# Epoch [65/200] 的训练集准确率: 72.69 %
# Epoch [65/200] 的训练集loss: 0.80 %
# Epoch [65/200] 的验证集准确率: 55.36 %
# Epoch [65/200] 的验证集loss: 1.31 %
# ------------------------------
# ------------------------------
# Epoch [66/200] 的训练集准确率: 74.17 %
# Epoch [66/200] 的训练集loss: 0.77 %
# Epoch [66/200] 的验证集准确率: 55.42 %
# Epoch [66/200] 的验证集loss: 1.29 %
# ------------------------------
# ------------------------------
# Epoch [67/200] 的训练集准确率: 74.82 %
# Epoch [67/200] 的训练集loss: 0.76 %
# Epoch [67/200] 的验证集准确率: 55.56 %
# Epoch [67/200] 的验证集loss: 1.28 %
# ------------------------------
# ------------------------------
# Epoch [68/200] 的训练集准确率: 74.95 %
# Epoch [68/200] 的训练集loss: 0.75 %
# Epoch [68/200] 的验证集准确率: 55.32 %
# Epoch [68/200] 的验证集loss: 1.28 %
# ------------------------------
# ------------------------------
# Epoch [69/200] 的训练集准确率: 73.93 %
# Epoch [69/200] 的训练集loss: 0.76 %
# Epoch [69/200] 的验证集准确率: 55.22 %
# Epoch [69/200] 的验证集loss: 1.31 %
# ------------------------------
# ------------------------------
# Epoch [70/200] 的训练集准确率: 74.22 %
# Epoch [70/200] 的训练集loss: 0.75 %
# Epoch [70/200] 的验证集准确率: 55.26 %
# Epoch [70/200] 的验证集loss: 1.32 %
# ------------------------------
# ------------------------------
# Epoch [71/200] 的训练集准确率: 74.65 %
# Epoch [71/200] 的训练集loss: 0.74 %
# Epoch [71/200] 的验证集准确率: 55.40 %
# Epoch [71/200] 的验证集loss: 1.31 %
# ------------------------------
# ------------------------------
# Epoch [72/200] 的训练集准确率: 74.82 %
# Epoch [72/200] 的训练集loss: 0.74 %
# Epoch [72/200] 的验证集准确率: 55.80 %
# Epoch [72/200] 的验证集loss: 1.32 %
# ------------------------------
# ------------------------------
# Epoch [73/200] 的训练集准确率: 75.82 %
# Epoch [73/200] 的训练集loss: 0.73 %
# Epoch [73/200] 的验证集准确率: 55.68 %
# Epoch [73/200] 的验证集loss: 1.31 %
# ------------------------------
# ------------------------------
# Epoch [74/200] 的训练集准确率: 75.64 %
# Epoch [74/200] 的训练集loss: 0.71 %
# Epoch [74/200] 的验证集准确率: 55.90 %
# Epoch [74/200] 的验证集loss: 1.33 %
# ------------------------------
# ------------------------------
# Epoch [75/200] 的训练集准确率: 76.24 %
# Epoch [75/200] 的训练集loss: 0.71 %
# Epoch [75/200] 的验证集准确率: 56.08 %
# Epoch [75/200] 的验证集loss: 1.31 %
# ------------------------------
# ------------------------------
# Epoch [76/200] 的训练集准确率: 76.62 %
# Epoch [76/200] 的训练集loss: 0.69 %
# Epoch [76/200] 的验证集准确率: 56.34 %
# Epoch [76/200] 的验证集loss: 1.30 %
# 发现更好的模型，已保存到 best_model.pth
# ------------------------------
# ------------------------------
# Epoch [77/200] 的训练集准确率: 76.57 %
# Epoch [77/200] 的训练集loss: 0.70 %
# Epoch [77/200] 的验证集准确率: 55.54 %
# Epoch [77/200] 的验证集loss: 1.32 %
# ------------------------------
# ------------------------------
# Epoch [78/200] 的训练集准确率: 77.55 %
# Epoch [78/200] 的训练集loss: 0.67 %
# Epoch [78/200] 的验证集准确率: 55.02 %
# Epoch [78/200] 的验证集loss: 1.32 %
# ------------------------------
# ------------------------------
# Epoch [79/200] 的训练集准确率: 77.58 %
# Epoch [79/200] 的训练集loss: 0.67 %
# Epoch [79/200] 的验证集准确率: 56.56 %
# Epoch [79/200] 的验证集loss: 1.32 %
# 发现更好的模型，已保存到 best_model.pth
# ------------------------------
# ------------------------------
# Epoch [80/200] 的训练集准确率: 77.88 %
# Epoch [80/200] 的训练集loss: 0.66 %
# Epoch [80/200] 的验证集准确率: 55.46 %
# Epoch [80/200] 的验证集loss: 1.34 %
# ------------------------------
# ------------------------------
# Epoch [81/200] 的训练集准确率: 78.48 %
# Epoch [81/200] 的训练集loss: 0.65 %
# Epoch [81/200] 的验证集准确率: 56.06 %
# Epoch [81/200] 的验证集loss: 1.33 %
# ------------------------------
# ------------------------------
# Epoch [82/200] 的训练集准确率: 78.96 %
# Epoch [82/200] 的训练集loss: 0.64 %
# Epoch [82/200] 的验证集准确率: 55.96 %
# Epoch [82/200] 的验证集loss: 1.33 %
# ------------------------------
# ------------------------------
# Epoch [83/200] 的训练集准确率: 80.00 %
# Epoch [83/200] 的训练集loss: 0.61 %
# Epoch [83/200] 的验证集准确率: 56.26 %
# Epoch [83/200] 的验证集loss: 1.33 %
# ------------------------------
# ------------------------------
# Epoch [84/200] 的训练集准确率: 78.38 %
# Epoch [84/200] 的训练集loss: 0.64 %
# Epoch [84/200] 的验证集准确率: 56.08 %
# Epoch [84/200] 的验证集loss: 1.36 %
# ------------------------------
# ------------------------------
# Epoch [85/200] 的训练集准确率: 78.80 %
# Epoch [85/200] 的训练集loss: 0.64 %
# Epoch [85/200] 的验证集准确率: 55.52 %
# Epoch [85/200] 的验证集loss: 1.35 %
# ------------------------------
# ------------------------------
# Epoch [86/200] 的训练集准确率: 79.96 %
# Epoch [86/200] 的训练集loss: 0.61 %
# Epoch [86/200] 的验证集准确率: 56.02 %
# Epoch [86/200] 的验证集loss: 1.34 %
# ------------------------------
# ------------------------------
# Epoch [87/200] 的训练集准确率: 78.81 %
# Epoch [87/200] 的训练集loss: 0.63 %
# Epoch [87/200] 的验证集准确率: 55.32 %
# Epoch [87/200] 的验证集loss: 1.36 %
# ------------------------------
# ------------------------------
# Epoch [88/200] 的训练集准确率: 79.30 %
# Epoch [88/200] 的训练集loss: 0.61 %
# Epoch [88/200] 的验证集准确率: 54.68 %
# Epoch [88/200] 的验证集loss: 1.36 %
# ------------------------------
# ------------------------------
# Epoch [89/200] 的训练集准确率: 80.19 %
# Epoch [89/200] 的训练集loss: 0.60 %
# Epoch [89/200] 的验证集准确率: 55.14 %
# Epoch [89/200] 的验证集loss: 1.36 %
# ------------------------------
# ------------------------------
# Epoch [90/200] 的训练集准确率: 80.09 %
# Epoch [90/200] 的训练集loss: 0.60 %
# Epoch [90/200] 的验证集准确率: 55.26 %
# Epoch [90/200] 的验证集loss: 1.38 %
# ------------------------------
# ------------------------------
# Epoch [91/200] 的训练集准确率: 81.38 %
# Epoch [91/200] 的训练集loss: 0.58 %
# Epoch [91/200] 的验证集准确率: 55.50 %
# Epoch [91/200] 的验证集loss: 1.37 %
# ------------------------------
# ------------------------------
# Epoch [92/200] 的训练集准确率: 82.15 %
# Epoch [92/200] 的训练集loss: 0.55 %
# Epoch [92/200] 的验证集准确率: 56.26 %
# Epoch [92/200] 的验证集loss: 1.36 %
# ------------------------------
# ------------------------------
# Epoch [93/200] 的训练集准确率: 81.72 %
# Epoch [93/200] 的训练集loss: 0.55 %
# Epoch [93/200] 的验证集准确率: 56.14 %
# Epoch [93/200] 的验证集loss: 1.38 %
# ------------------------------
# ------------------------------
# Epoch [94/200] 的训练集准确率: 81.89 %
# Epoch [94/200] 的训练集loss: 0.55 %
# Epoch [94/200] 的验证集准确率: 56.84 %
# Epoch [94/200] 的验证集loss: 1.39 %
# 发现更好的模型，已保存到 best_model.pth
# ------------------------------
# ------------------------------
# Epoch [95/200] 的训练集准确率: 83.16 %
# Epoch [95/200] 的训练集loss: 0.52 %
# Epoch [95/200] 的验证集准确率: 56.36 %
# Epoch [95/200] 的验证集loss: 1.38 %
# ------------------------------
# ------------------------------
# Epoch [96/200] 的训练集准确率: 83.08 %
# Epoch [96/200] 的训练集loss: 0.53 %
# Epoch [96/200] 的验证集准确率: 56.08 %
# Epoch [96/200] 的验证集loss: 1.38 %
# ------------------------------
# ------------------------------
# Epoch [97/200] 的训练集准确率: 83.75 %
# Epoch [97/200] 的训练集loss: 0.51 %
# Epoch [97/200] 的验证集准确率: 56.24 %
# Epoch [97/200] 的验证集loss: 1.39 %
# ------------------------------
# ------------------------------
# Epoch [98/200] 的训练集准确率: 83.63 %
# Epoch [98/200] 的训练集loss: 0.51 %
# Epoch [98/200] 的验证集准确率: 56.06 %
# Epoch [98/200] 的验证集loss: 1.39 %
# ------------------------------
# ------------------------------
# Epoch [99/200] 的训练集准确率: 83.67 %
# Epoch [99/200] 的训练集loss: 0.51 %
# Epoch [99/200] 的验证集准确率: 55.88 %
# Epoch [99/200] 的验证集loss: 1.41 %
# ------------------------------
# ------------------------------
# Epoch [100/200] 的训练集准确率: 83.94 %
# Epoch [100/200] 的训练集loss: 0.52 %
# Epoch [100/200] 的验证集准确率: 55.40 %
# Epoch [100/200] 的验证集loss: 1.41 %
# ------------------------------
# ------------------------------
# Epoch [101/200] 的训练集准确率: 84.42 %
# Epoch [101/200] 的训练集loss: 0.49 %
# Epoch [101/200] 的验证集准确率: 56.20 %
# Epoch [101/200] 的验证集loss: 1.40 %
# ------------------------------
# ------------------------------
# Epoch [102/200] 的训练集准确率: 84.61 %
# Epoch [102/200] 的训练集loss: 0.50 %
# Epoch [102/200] 的验证集准确率: 55.26 %
# Epoch [102/200] 的验证集loss: 1.40 %
# ------------------------------
# ------------------------------
# Epoch [103/200] 的训练集准确率: 84.55 %
# Epoch [103/200] 的训练集loss: 0.48 %
# Epoch [103/200] 的验证集准确率: 55.86 %
# Epoch [103/200] 的验证集loss: 1.43 %
# ------------------------------
# ------------------------------
# Epoch [104/200] 的训练集准确率: 84.04 %
# Epoch [104/200] 的训练集loss: 0.49 %
# Epoch [104/200] 的验证集准确率: 55.90 %
# Epoch [104/200] 的验证集loss: 1.44 %
# ------------------------------
# ------------------------------
# Epoch [105/200] 的训练集准确率: 85.28 %
# Epoch [105/200] 的训练集loss: 0.47 %
# Epoch [105/200] 的验证集准确率: 55.80 %
# Epoch [105/200] 的验证集loss: 1.43 %
# ------------------------------
# ------------------------------
# Epoch [106/200] 的训练集准确率: 84.91 %
# Epoch [106/200] 的训练集loss: 0.46 %
# Epoch [106/200] 的验证集准确率: 55.80 %
# Epoch [106/200] 的验证集loss: 1.44 %
# ------------------------------
# ------------------------------
# Epoch [107/200] 的训练集准确率: 84.83 %
# Epoch [107/200] 的训练集loss: 0.48 %
# Epoch [107/200] 的验证集准确率: 55.22 %
# Epoch [107/200] 的验证集loss: 1.45 %
# ------------------------------
# ------------------------------
# Epoch [108/200] 的训练集准确率: 85.05 %
# Epoch [108/200] 的训练集loss: 0.47 %
# Epoch [108/200] 的验证集准确率: 55.58 %
# Epoch [108/200] 的验证集loss: 1.46 %
# ------------------------------
# ------------------------------
# Epoch [109/200] 的训练集准确率: 84.82 %
# Epoch [109/200] 的训练集loss: 0.48 %
# Epoch [109/200] 的验证集准确率: 56.10 %
# Epoch [109/200] 的验证集loss: 1.45 %
# ------------------------------
# ------------------------------
# Epoch [110/200] 的训练集准确率: 86.64 %
# Epoch [110/200] 的训练集loss: 0.45 %
# Epoch [110/200] 的验证集准确率: 56.82 %
# Epoch [110/200] 的验证集loss: 1.41 %
# ------------------------------
# ------------------------------
# Epoch [111/200] 的训练集准确率: 86.62 %
# Epoch [111/200] 的训练集loss: 0.43 %
# Epoch [111/200] 的验证集准确率: 56.58 %
# Epoch [111/200] 的验证集loss: 1.47 %
# ------------------------------
# ------------------------------
# Epoch [112/200] 的训练集准确率: 86.71 %
# Epoch [112/200] 的训练集loss: 0.42 %
# Epoch [112/200] 的验证集准确率: 56.02 %
# Epoch [112/200] 的验证集loss: 1.46 %
# ------------------------------
# ------------------------------
# Epoch [113/200] 的训练集准确率: 87.76 %
# Epoch [113/200] 的训练集loss: 0.40 %
# Epoch [113/200] 的验证集准确率: 56.58 %
# Epoch [113/200] 的验证集loss: 1.46 %
# ------------------------------
# ------------------------------
# Epoch [114/200] 的训练集准确率: 88.22 %
# Epoch [114/200] 的训练集loss: 0.40 %
# Epoch [114/200] 的验证集准确率: 55.86 %
# Epoch [114/200] 的验证集loss: 1.47 %
# ------------------------------
# ------------------------------
# Epoch [115/200] 的训练集准确率: 86.31 %
# Epoch [115/200] 的训练集loss: 0.43 %
# Epoch [115/200] 的验证集准确率: 55.56 %
# Epoch [115/200] 的验证集loss: 1.49 %
# ------------------------------
# ------------------------------
# Epoch [116/200] 的训练集准确率: 87.92 %
# Epoch [116/200] 的训练集loss: 0.40 %
# Epoch [116/200] 的验证集准确率: 55.68 %
# Epoch [116/200] 的验证集loss: 1.45 %
# ------------------------------
# ------------------------------
# Epoch [117/200] 的训练集准确率: 88.44 %
# Epoch [117/200] 的训练集loss: 0.39 %
# Epoch [117/200] 的验证集准确率: 56.02 %
# Epoch [117/200] 的验证集loss: 1.47 %
# ------------------------------
# ------------------------------
# Epoch [118/200] 的训练集准确率: 88.27 %
# Epoch [118/200] 的训练集loss: 0.38 %
# Epoch [118/200] 的验证集准确率: 56.16 %
# Epoch [118/200] 的验证集loss: 1.49 %
# ------------------------------
# ------------------------------
# Epoch [119/200] 的训练集准确率: 87.44 %
# Epoch [119/200] 的训练集loss: 0.40 %
# Epoch [119/200] 的验证集准确率: 56.16 %
# Epoch [119/200] 的验证集loss: 1.49 %
# ------------------------------
# ------------------------------
# Epoch [120/200] 的训练集准确率: 88.56 %
# Epoch [120/200] 的训练集loss: 0.38 %
# Epoch [120/200] 的验证集准确率: 56.24 %
# Epoch [120/200] 的验证集loss: 1.51 %
# ------------------------------
# ------------------------------
# Epoch [121/200] 的训练集准确率: 88.94 %
# Epoch [121/200] 的训练集loss: 0.38 %
# Epoch [121/200] 的验证集准确率: 55.54 %
# Epoch [121/200] 的验证集loss: 1.49 %
# ------------------------------
# ------------------------------
# Epoch [122/200] 的训练集准确率: 88.36 %
# Epoch [122/200] 的训练集loss: 0.37 %
# Epoch [122/200] 的验证集准确率: 55.50 %
# Epoch [122/200] 的验证集loss: 1.55 %
# ------------------------------
# ------------------------------
# Epoch [123/200] 的训练集准确率: 89.28 %
# Epoch [123/200] 的训练集loss: 0.36 %
# Epoch [123/200] 的验证集准确率: 55.82 %
# Epoch [123/200] 的验证集loss: 1.50 %
# ------------------------------
# ------------------------------
# Epoch [124/200] 的训练集准确率: 88.94 %
# Epoch [124/200] 的训练集loss: 0.37 %
# Epoch [124/200] 的验证集准确率: 56.30 %
# Epoch [124/200] 的验证集loss: 1.52 %
# ------------------------------
# ------------------------------
# Epoch [125/200] 的训练集准确率: 90.16 %
# Epoch [125/200] 的训练集loss: 0.34 %
# Epoch [125/200] 的验证集准确率: 56.02 %
# Epoch [125/200] 的验证集loss: 1.51 %
# ------------------------------
# ------------------------------
# Epoch [126/200] 的训练集准确率: 89.21 %
# Epoch [126/200] 的训练集loss: 0.36 %
# Epoch [126/200] 的验证集准确率: 56.36 %
# Epoch [126/200] 的验证集loss: 1.52 %
# ------------------------------
# ------------------------------
# Epoch [127/200] 的训练集准确率: 90.31 %
# Epoch [127/200] 的训练集loss: 0.34 %
# Epoch [127/200] 的验证集准确率: 55.12 %
# Epoch [127/200] 的验证集loss: 1.52 %
# ------------------------------
# ------------------------------
# Epoch [128/200] 的训练集准确率: 89.57 %
# Epoch [128/200] 的训练集loss: 0.35 %
# Epoch [128/200] 的验证集准确率: 55.58 %
# Epoch [128/200] 的验证集loss: 1.52 %
# ------------------------------
# ------------------------------
# Epoch [129/200] 的训练集准确率: 89.55 %
# Epoch [129/200] 的训练集loss: 0.35 %
# Epoch [129/200] 的验证集准确率: 55.80 %
# Epoch [129/200] 的验证集loss: 1.57 %
# ------------------------------
# ------------------------------
# Epoch [130/200] 的训练集准确率: 90.24 %
# Epoch [130/200] 的训练集loss: 0.34 %
# Epoch [130/200] 的验证集准确率: 55.20 %
# Epoch [130/200] 的验证集loss: 1.53 %
# ------------------------------
# ------------------------------
# Epoch [131/200] 的训练集准确率: 89.38 %
# Epoch [131/200] 的训练集loss: 0.35 %
# Epoch [131/200] 的验证集准确率: 56.06 %
# Epoch [131/200] 的验证集loss: 1.55 %
# ------------------------------
# ------------------------------
# Epoch [132/200] 的训练集准确率: 90.44 %
# Epoch [132/200] 的训练集loss: 0.33 %
# Epoch [132/200] 的验证集准确率: 55.74 %
# Epoch [132/200] 的验证集loss: 1.54 %
# ------------------------------
# ------------------------------
# Epoch [133/200] 的训练集准确率: 91.18 %
# Epoch [133/200] 的训练集loss: 0.31 %
# Epoch [133/200] 的验证集准确率: 56.44 %
# Epoch [133/200] 的验证集loss: 1.55 %
# ------------------------------
# ------------------------------
# Epoch [134/200] 的训练集准确率: 90.72 %
# Epoch [134/200] 的训练集loss: 0.33 %
# Epoch [134/200] 的验证集准确率: 55.18 %
# Epoch [134/200] 的验证集loss: 1.58 %
# ------------------------------
# ------------------------------
# Epoch [135/200] 的训练集准确率: 90.91 %
# Epoch [135/200] 的训练集loss: 0.31 %
# Epoch [135/200] 的验证集准确率: 55.78 %
# Epoch [135/200] 的验证集loss: 1.57 %
# ------------------------------
# ------------------------------
# Epoch [136/200] 的训练集准确率: 91.69 %
# Epoch [136/200] 的训练集loss: 0.30 %
# Epoch [136/200] 的验证集准确率: 56.00 %
# Epoch [136/200] 的验证集loss: 1.57 %
# ------------------------------
# ------------------------------
# Epoch [137/200] 的训练集准确率: 91.98 %
# Epoch [137/200] 的训练集loss: 0.29 %
# Epoch [137/200] 的验证集准确率: 55.88 %
# Epoch [137/200] 的验证集loss: 1.58 %
# ------------------------------
# ------------------------------
# Epoch [138/200] 的训练集准确率: 91.98 %
# Epoch [138/200] 的训练集loss: 0.29 %
# Epoch [138/200] 的验证集准确率: 55.64 %
# Epoch [138/200] 的验证集loss: 1.60 %
# ------------------------------
# ------------------------------
# Epoch [139/200] 的训练集准确率: 91.66 %
# Epoch [139/200] 的训练集loss: 0.29 %
# Epoch [139/200] 的验证集准确率: 56.06 %
# Epoch [139/200] 的验证集loss: 1.60 %
# ------------------------------
# ------------------------------
# Epoch [140/200] 的训练集准确率: 92.60 %
# Epoch [140/200] 的训练集loss: 0.28 %
# Epoch [140/200] 的验证集准确率: 55.74 %
# Epoch [140/200] 的验证集loss: 1.58 %
# ------------------------------
# ------------------------------
# Epoch [141/200] 的训练集准确率: 91.61 %
# Epoch [141/200] 的训练集loss: 0.29 %
# Epoch [141/200] 的验证集准确率: 55.42 %
# Epoch [141/200] 的验证集loss: 1.61 %
# ------------------------------
# ------------------------------
# Epoch [142/200] 的训练集准确率: 91.22 %
# Epoch [142/200] 的训练集loss: 0.30 %
# Epoch [142/200] 的验证集准确率: 55.88 %
# Epoch [142/200] 的验证集loss: 1.65 %
# ------------------------------
# ------------------------------
# Epoch [143/200] 的训练集准确率: 91.48 %
# Epoch [143/200] 的训练集loss: 0.29 %
# Epoch [143/200] 的验证集准确率: 55.40 %
# Epoch [143/200] 的验证集loss: 1.64 %
# ------------------------------
# ------------------------------
# Epoch [144/200] 的训练集准确率: 91.88 %
# Epoch [144/200] 的训练集loss: 0.28 %
# Epoch [144/200] 的验证集准确率: 56.44 %
# Epoch [144/200] 的验证集loss: 1.62 %
# ------------------------------
# ------------------------------
# Epoch [145/200] 的训练集准确率: 92.71 %
# Epoch [145/200] 的训练集loss: 0.27 %
# Epoch [145/200] 的验证集准确率: 55.76 %
# Epoch [145/200] 的验证集loss: 1.60 %
# ------------------------------
# ------------------------------
# Epoch [146/200] 的训练集准确率: 92.29 %
# Epoch [146/200] 的训练集loss: 0.28 %
# Epoch [146/200] 的验证集准确率: 55.22 %
# Epoch [146/200] 的验证集loss: 1.63 %
# ------------------------------
# ------------------------------
# Epoch [147/200] 的训练集准确率: 92.26 %
# Epoch [147/200] 的训练集loss: 0.27 %
# Epoch [147/200] 的验证集准确率: 55.60 %
# Epoch [147/200] 的验证集loss: 1.64 %
# ------------------------------
# ------------------------------
# Epoch [148/200] 的训练集准确率: 92.56 %
# Epoch [148/200] 的训练集loss: 0.26 %
# Epoch [148/200] 的验证集准确率: 54.88 %
# Epoch [148/200] 的验证集loss: 1.66 %
# ------------------------------
# ------------------------------
# Epoch [149/200] 的训练集准确率: 93.19 %
# Epoch [149/200] 的训练集loss: 0.25 %
# Epoch [149/200] 的验证集准确率: 56.48 %
# Epoch [149/200] 的验证集loss: 1.61 %
# ------------------------------
# ------------------------------
# Epoch [150/200] 的训练集准确率: 93.71 %
# Epoch [150/200] 的训练集loss: 0.24 %
# Epoch [150/200] 的验证集准确率: 55.92 %
# Epoch [150/200] 的验证集loss: 1.64 %
# ------------------------------
# ------------------------------
# Epoch [151/200] 的训练集准确率: 92.72 %
# Epoch [151/200] 的训练集loss: 0.26 %
# Epoch [151/200] 的验证集准确率: 55.74 %
# Epoch [151/200] 的验证集loss: 1.68 %
# ------------------------------
# ------------------------------
# Epoch [152/200] 的训练集准确率: 93.21 %
# Epoch [152/200] 的训练集loss: 0.25 %
# Epoch [152/200] 的验证集准确率: 55.84 %
# Epoch [152/200] 的验证集loss: 1.68 %
# ------------------------------
# ------------------------------
# Epoch [153/200] 的训练集准确率: 93.43 %
# Epoch [153/200] 的训练集loss: 0.25 %
# Epoch [153/200] 的验证集准确率: 55.72 %
# Epoch [153/200] 的验证集loss: 1.66 %
# ------------------------------
# ------------------------------
# Epoch [154/200] 的训练集准确率: 94.02 %
# Epoch [154/200] 的训练集loss: 0.23 %
# Epoch [154/200] 的验证集准确率: 55.96 %
# Epoch [154/200] 的验证集loss: 1.65 %
# ------------------------------
# ------------------------------
# Epoch [155/200] 的训练集准确率: 93.99 %
# Epoch [155/200] 的训练集loss: 0.23 %
# Epoch [155/200] 的验证集准确率: 55.38 %
# Epoch [155/200] 的验证集loss: 1.66 %
# ------------------------------
# ------------------------------
# Epoch [156/200] 的训练集准确率: 93.75 %
# Epoch [156/200] 的训练集loss: 0.23 %
# Epoch [156/200] 的验证集准确率: 56.00 %
# Epoch [156/200] 的验证集loss: 1.67 %
# ------------------------------
# ------------------------------
# Epoch [157/200] 的训练集准确率: 93.84 %
# Epoch [157/200] 的训练集loss: 0.23 %
# Epoch [157/200] 的验证集准确率: 56.44 %
# Epoch [157/200] 的验证集loss: 1.64 %
# ------------------------------
# ------------------------------
# Epoch [158/200] 的训练集准确率: 93.21 %
# Epoch [158/200] 的训练集loss: 0.25 %
# Epoch [158/200] 的验证集准确率: 54.84 %
# Epoch [158/200] 的验证集loss: 1.70 %
# ------------------------------
# ------------------------------
# Epoch [159/200] 的训练集准确率: 94.24 %
# Epoch [159/200] 的训练集loss: 0.22 %
# Epoch [159/200] 的验证集准确率: 55.74 %
# Epoch [159/200] 的验证集loss: 1.69 %
# ------------------------------
# ------------------------------
# Epoch [160/200] 的训练集准确率: 93.42 %
# Epoch [160/200] 的训练集loss: 0.24 %
# Epoch [160/200] 的验证集准确率: 55.76 %
# Epoch [160/200] 的验证集loss: 1.71 %
# ------------------------------
# ------------------------------
# Epoch [161/200] 的训练集准确率: 93.33 %
# Epoch [161/200] 的训练集loss: 0.24 %
# Epoch [161/200] 的验证集准确率: 55.08 %
# Epoch [161/200] 的验证集loss: 1.73 %
# ------------------------------
# ------------------------------
# Epoch [162/200] 的训练集准确率: 93.35 %
# Epoch [162/200] 的训练集loss: 0.24 %
# Epoch [162/200] 的验证集准确率: 55.00 %
# Epoch [162/200] 的验证集loss: 1.71 %
# ------------------------------
# ------------------------------
# Epoch [163/200] 的训练集准确率: 94.30 %
# Epoch [163/200] 的训练集loss: 0.21 %
# Epoch [163/200] 的验证集准确率: 55.88 %
# Epoch [163/200] 的验证集loss: 1.72 %
# ------------------------------
# ------------------------------
# Epoch [164/200] 的训练集准确率: 94.17 %
# Epoch [164/200] 的训练集loss: 0.22 %
# Epoch [164/200] 的验证集准确率: 55.36 %
# Epoch [164/200] 的验证集loss: 1.76 %
# ------------------------------
# ------------------------------
# Epoch [165/200] 的训练集准确率: 94.54 %
# Epoch [165/200] 的训练集loss: 0.21 %
# Epoch [165/200] 的验证集准确率: 54.84 %
# Epoch [165/200] 的验证集loss: 1.72 %
# ------------------------------
# ------------------------------
# Epoch [166/200] 的训练集准确率: 94.06 %
# Epoch [166/200] 的训练集loss: 0.22 %
# Epoch [166/200] 的验证集准确率: 55.24 %
# Epoch [166/200] 的验证集loss: 1.74 %
# ------------------------------
# ------------------------------
# Epoch [167/200] 的训练集准确率: 94.80 %
# Epoch [167/200] 的训练集loss: 0.20 %
# Epoch [167/200] 的验证集准确率: 55.54 %
# Epoch [167/200] 的验证集loss: 1.75 %
# ------------------------------
# ------------------------------
# Epoch [168/200] 的训练集准确率: 95.08 %
# Epoch [168/200] 的训练集loss: 0.19 %
# Epoch [168/200] 的验证集准确率: 55.48 %
# Epoch [168/200] 的验证集loss: 1.73 %
# ------------------------------
# ------------------------------
# Epoch [169/200] 的训练集准确率: 94.79 %
# Epoch [169/200] 的训练集loss: 0.20 %
# Epoch [169/200] 的验证集准确率: 55.52 %
# Epoch [169/200] 的验证集loss: 1.78 %
# ------------------------------
# ------------------------------
# Epoch [170/200] 的训练集准确率: 94.93 %
# Epoch [170/200] 的训练集loss: 0.20 %
# Epoch [170/200] 的验证集准确率: 55.54 %
# Epoch [170/200] 的验证集loss: 1.75 %
# ------------------------------
# ------------------------------
# Epoch [171/200] 的训练集准确率: 95.27 %
# Epoch [171/200] 的训练集loss: 0.19 %
# Epoch [171/200] 的验证集准确率: 55.36 %
# Epoch [171/200] 的验证集loss: 1.75 %
# ------------------------------
# ------------------------------
# Epoch [172/200] 的训练集准确率: 95.23 %
# Epoch [172/200] 的训练集loss: 0.19 %
# Epoch [172/200] 的验证集准确率: 56.18 %
# Epoch [172/200] 的验证集loss: 1.74 %
# ------------------------------
# ------------------------------
# Epoch [173/200] 的训练集准确率: 95.31 %
# Epoch [173/200] 的训练集loss: 0.19 %
# Epoch [173/200] 的验证集准确率: 55.00 %
# Epoch [173/200] 的验证集loss: 1.76 %
# ------------------------------
# ------------------------------
# Epoch [174/200] 的训练集准确率: 95.55 %
# Epoch [174/200] 的训练集loss: 0.18 %
# Epoch [174/200] 的验证集准确率: 55.82 %
# Epoch [174/200] 的验证集loss: 1.74 %
# ------------------------------
# ------------------------------
# Epoch [175/200] 的训练集准确率: 95.02 %
# Epoch [175/200] 的训练集loss: 0.19 %
# Epoch [175/200] 的验证集准确率: 56.08 %
# Epoch [175/200] 的验证集loss: 1.78 %
# ------------------------------
# ------------------------------
# Epoch [176/200] 的训练集准确率: 95.26 %
# Epoch [176/200] 的训练集loss: 0.19 %
# Epoch [176/200] 的验证集准确率: 55.14 %
# Epoch [176/200] 的验证集loss: 1.78 %
# ------------------------------
# ------------------------------
# Epoch [177/200] 的训练集准确率: 95.52 %
# Epoch [177/200] 的训练集loss: 0.18 %
# Epoch [177/200] 的验证集准确率: 55.68 %
# Epoch [177/200] 的验证集loss: 1.78 %
# ------------------------------
# ------------------------------
# Epoch [178/200] 的训练集准确率: 95.52 %
# Epoch [178/200] 的训练集loss: 0.18 %
# Epoch [178/200] 的验证集准确率: 55.36 %
# Epoch [178/200] 的验证集loss: 1.79 %
# ------------------------------
# ------------------------------
# Epoch [179/200] 的训练集准确率: 95.41 %
# Epoch [179/200] 的训练集loss: 0.18 %
# Epoch [179/200] 的验证集准确率: 55.50 %
# Epoch [179/200] 的验证集loss: 1.77 %
# ------------------------------
# ------------------------------
# Epoch [180/200] 的训练集准确率: 95.24 %
# Epoch [180/200] 的训练集loss: 0.19 %
# Epoch [180/200] 的验证集准确率: 54.64 %
# Epoch [180/200] 的验证集loss: 1.80 %
# ------------------------------
# ------------------------------
# Epoch [181/200] 的训练集准确率: 95.05 %
# Epoch [181/200] 的训练集loss: 0.19 %
# Epoch [181/200] 的验证集准确率: 55.46 %
# Epoch [181/200] 的验证集loss: 1.82 %
# ------------------------------
# ------------------------------
# Epoch [182/200] 的训练集准确率: 95.97 %
# Epoch [182/200] 的训练集loss: 0.17 %
# Epoch [182/200] 的验证集准确率: 55.40 %
# Epoch [182/200] 的验证集loss: 1.80 %
# ------------------------------
# ------------------------------
# Epoch [183/200] 的训练集准确率: 95.66 %
# Epoch [183/200] 的训练集loss: 0.17 %
# Epoch [183/200] 的验证集准确率: 55.32 %
# Epoch [183/200] 的验证集loss: 1.81 %
# ------------------------------
# ------------------------------
# Epoch [184/200] 的训练集准确率: 95.53 %
# Epoch [184/200] 的训练集loss: 0.17 %
# Epoch [184/200] 的验证集准确率: 55.28 %
# Epoch [184/200] 的验证集loss: 1.82 %
# ------------------------------
# ------------------------------
# Epoch [185/200] 的训练集准确率: 96.12 %
# Epoch [185/200] 的训练集loss: 0.16 %
# Epoch [185/200] 的验证集准确率: 55.78 %
# Epoch [185/200] 的验证集loss: 1.79 %
# ------------------------------
# ------------------------------
# Epoch [186/200] 的训练集准确率: 95.93 %
# Epoch [186/200] 的训练集loss: 0.16 %
# Epoch [186/200] 的验证集准确率: 55.42 %
# Epoch [186/200] 的验证集loss: 1.87 %
# ------------------------------
# ------------------------------
# Epoch [187/200] 的训练集准确率: 95.81 %
# Epoch [187/200] 的训练集loss: 0.16 %
# Epoch [187/200] 的验证集准确率: 55.50 %
# Epoch [187/200] 的验证集loss: 1.84 %
# ------------------------------
# ------------------------------
# Epoch [188/200] 的训练集准确率: 96.17 %
# Epoch [188/200] 的训练集loss: 0.16 %
# Epoch [188/200] 的验证集准确率: 55.54 %
# Epoch [188/200] 的验证集loss: 1.83 %
# ------------------------------
# ------------------------------
# Epoch [189/200] 的训练集准确率: 95.57 %
# Epoch [189/200] 的训练集loss: 0.17 %
# Epoch [189/200] 的验证集准确率: 55.42 %
# Epoch [189/200] 的验证集loss: 1.84 %
# ------------------------------
# ------------------------------
# Epoch [190/200] 的训练集准确率: 96.07 %
# Epoch [190/200] 的训练集loss: 0.16 %
# Epoch [190/200] 的验证集准确率: 55.68 %
# Epoch [190/200] 的验证集loss: 1.87 %
# ------------------------------
# ------------------------------
# Epoch [191/200] 的训练集准确率: 96.88 %
# Epoch [191/200] 的训练集loss: 0.14 %
# Epoch [191/200] 的验证集准确率: 55.80 %
# Epoch [191/200] 的验证集loss: 1.81 %
# ------------------------------
# ------------------------------
# Epoch [192/200] 的训练集准确率: 95.90 %
# Epoch [192/200] 的训练集loss: 0.17 %
# Epoch [192/200] 的验证集准确率: 54.80 %
# Epoch [192/200] 的验证集loss: 1.88 %
# ------------------------------
# ------------------------------
# Epoch [193/200] 的训练集准确率: 95.97 %
# Epoch [193/200] 的训练集loss: 0.16 %
# Epoch [193/200] 的验证集准确率: 55.04 %
# Epoch [193/200] 的验证集loss: 1.87 %
# ------------------------------
# ------------------------------
# Epoch [194/200] 的训练集准确率: 96.79 %
# Epoch [194/200] 的训练集loss: 0.14 %
# Epoch [194/200] 的验证集准确率: 55.30 %
# Epoch [194/200] 的验证集loss: 1.83 %
# ------------------------------
# ------------------------------
# Epoch [195/200] 的训练集准确率: 97.01 %
# Epoch [195/200] 的训练集loss: 0.13 %
# Epoch [195/200] 的验证集准确率: 55.66 %
# Epoch [195/200] 的验证集loss: 1.86 %
# ------------------------------
# ------------------------------
# Epoch [196/200] 的训练集准确率: 95.86 %
# Epoch [196/200] 的训练集loss: 0.17 %
# Epoch [196/200] 的验证集准确率: 55.52 %
# Epoch [196/200] 的验证集loss: 1.87 %
# ------------------------------
# ------------------------------
# Epoch [197/200] 的训练集准确率: 96.36 %
# Epoch [197/200] 的训练集loss: 0.15 %
# Epoch [197/200] 的验证集准确率: 55.60 %
# Epoch [197/200] 的验证集loss: 1.90 %
# ------------------------------
# ------------------------------
# Epoch [198/200] 的训练集准确率: 95.54 %
# Epoch [198/200] 的训练集loss: 0.17 %
# Epoch [198/200] 的验证集准确率: 55.30 %
# Epoch [198/200] 的验证集loss: 1.89 %
# ------------------------------
# ------------------------------
# Epoch [199/200] 的训练集准确率: 97.14 %
# Epoch [199/200] 的训练集loss: 0.13 %
# Epoch [199/200] 的验证集准确率: 55.94 %
# Epoch [199/200] 的验证集loss: 1.87 %
# ------------------------------
# ------------------------------
# Epoch [200/200] 的训练集准确率: 97.07 %
# Epoch [200/200] 的训练集loss: 0.13 %
# Epoch [200/200] 的验证集准确率: 55.66 %
# Epoch [200/200] 的验证集loss: 1.88 %
# ------------------------------
# 加载最佳模型 (best_model.pth) 进行最终测试...
# 测试集准确率: 55.79 %
# 测试集loss: 1.39 %
